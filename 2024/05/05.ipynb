# %%
def parse_file(file):
    with open(file, "r") as f:
        rules, updates = f.read().split("\n\n")
    rules = filter(lambda x: len(x) > 0, rules.split("\n"))
    rules = [tuple(map(int, rule.split("|"))) for rule in rules]
    updates = filter(lambda x: len(x.strip()) > 0, updates.split("\n"))
    updates = [tuple(map(int, update.split(","))) for update in updates]
    return rules, updates


import pandas as pd


def create_graph(rules):
    graph = pd.DataFrame(rules)
    graph.columns = ["smaller", "greater"]
    n_to_greaters = graph.groupby("smaller")["greater"].agg(set).to_dict()
    n_to_smallers = graph.groupby("greater")["smaller"].agg(set).to_dict()
    return n_to_greaters, n_to_smallers

# %%
def check_update_valid(update, n_to_greaters, n_to_smallers):
    for i in range(len(update)):
        number = update[i]
        prev_numbers = set(update[:i])
        # print(prev_numbers,  n_to_greaters.get(number, set()), prev_numbers & n_to_greaters.get(number, set()))
        if prev_numbers and (prev_numbers & n_to_greaters.get(number, set())):
            return False
        next_numbers = set(update[i + 1 :])
        # print(next_numbers, n_to_smallers.get(number, set()), next_numbers & n_to_smallers.get(number, set()))
        if next_numbers and (next_numbers & n_to_smallers.get(number, set())):
            return False
    return True


def total_middle_valid(updates, n_to_greaters, n_to_smallers):
    total = 0
    for update in updates:
        is_valid = check_update_valid(update, n_to_greaters, n_to_smallers)
        if is_valid:
            central_number = update[len(update) // 2]
            total += central_number
    return total


rules, updates = parse_file("input.txt")
n_to_greaters, n_to_smallers = create_graph(rules)
print(n_to_greaters)
print(n_to_smallers)
print(total_middle_valid(updates, n_to_greaters, n_to_smallers))
# Out:
# {11: {16, 17, 24, 25, 26, 28, 29, 31, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 12: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 14: {11, 12, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 16: {14, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 84, 87, 88, 96, 97}, 17: {14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 22: {11, 16, 17, 24, 25, 27, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 24: {14, 16, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 25: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 96, 98}, 26: {12, 14, 22, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 27: {11, 16, 17, 24, 25, 26, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 28: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 29: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 76, 77, 79, 82, 84, 87, 88, 96}, 31: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 32: {12, 14, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 33: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 65, 67, 76, 77, 78, 87, 93, 97}, 34: {12, 14, 26, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 38: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 43, 47, 52, 55, 56, 57, 63, 65, 67, 76, 77, 78, 93, 97}, 43: {14, 17, 25, 26, 32, 34, 44, 45, 47, 51, 58, 64, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96, 98}, 44: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 93, 94, 98}, 45: {11, 12, 22, 27, 31, 33, 38, 44, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 47: {14, 17, 25, 26, 32, 34, 44, 45, 51, 58, 64, 67, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 49: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 47, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 51: {11, 12, 22, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 52: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 55: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 56: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 58, 64, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 57: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 84, 87, 96, 97}, 58: {11, 12, 22, 27, 28, 31, 33, 38, 49, 51, 52, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 63: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 97}, 64: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 65, 76, 77, 78, 81, 93, 97, 98}, 65: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 67: {14, 17, 25, 26, 32, 34, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 72: {11, 12, 16, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 94, 97, 98}, 73: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 76, 78, 81, 93, 97, 98}, 75: {12, 14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 79, 81, 82, 88, 94, 96, 98}, 76: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 77, 79, 82, 84, 87, 88, 94, 96}, 77: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 78: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 75, 76, 77, 84, 87, 93, 97}, 79: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 57, 58, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 81: {11, 12, 16, 22,  ...
# {11: {12, 14, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 12: {14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 14: {16, 17, 24, 25, 26, 28, 29, 31, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 16: {11, 12, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 93, 94, 98}, 17: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 22: {12, 14, 26, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 24: {11, 12, 22, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 25: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 75, 76, 77, 84, 87, 93, 97}, 26: {11, 16, 17, 24, 25, 27, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 27: {12, 14, 22, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 28: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 57, 58, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 29: {11, 12, 16, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 94, 97, 98}, 31: {11, 12, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 32: {11, 16, 17, 24, 25, 26, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 33: {14, 17, 25, 26, 32, 34, 38, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 88, 94, 96, 98}, 34: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 38: {14, 17, 25, 26, 32, 34, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 43: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 56, 57, 63, 65, 76, 77, 78, 81, 93, 97}, 44: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 45, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 96, 97}, 45: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 47: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 49, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 49: {14, 17, 25, 26, 32, 34, 44, 45, 51, 58, 64, 67, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 51: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 52: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 55: {11, 12, 22, 27, 28, 31, 33, 38, 49, 51, 52, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 56: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 65, 76, 77, 78, 81, 93, 97, 98}, 57: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 93, 94, 98}, 58: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 63: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 96, 98}, 64: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 65: {14, 17, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 67: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 47, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 72: {14, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 82, 84, 87, 88, 96}, 73: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 77, 79, 82, 84, 87, 88, 94, 96}, 75: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 76: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 97, 98}, 77: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 76, 78, 81, 93, 97, 98}, 78: {12, 14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 79, 81, 82, 88, 94, 96, 98}, 79: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 84, 87, 96, 97}, 81: {14, 17, 25, 26,  ...
# 5248

# %%
class Code(int):
    def __init__(self, value):
        self.value = value

    def __lt__(self, other):
        # define in negative way
        # if self < other, then not (self > other)
        # other < self
        x = self.value
        y = other.value

        """
        y in n_to_smallers.get(x, set()) -> y < x
        y in n_to_greaters.get(x, set()) -> x < y
        x in n_to_smallers.get(y, set()) -> x < y
        x in n_to_greaters.get(y, set()) -> y < x
        """
        if (y in n_to_greaters.get(x, set())) or (x in n_to_smallers.get(y, set())):
            return True
        elif (y in n_to_smallers.get(x, set())) or (x in n_to_greaters.get(y, set())):
            return False
        elif self.value == other.value:
            return False
        else:
            return x < y

    def __gt__(self, other):
        return other.__lt__(self)

    def __eq__(self, other):
        return self.value == other.value

    def __repr__(self) -> str:
        return f"<{self.value}>"

    def __hash__(self) -> int:
        return hash(self.value)


def total_middle_valid_correcting(updates, n_to_greaters, n_to_smallers):
    total = 0
    for update in updates:
        is_valid = check_update_valid(update, n_to_greaters, n_to_smallers)
        if is_valid:
            central_number = 0
            # central_number = update[len(update)//2]
        else:
            codes = [Code(i) for i in update]
            codes.sort()
            central_number = codes[len(codes) // 2].value

        total += central_number

    return total

# %%
rules, updates = parse_file("input.txt")
n_to_greaters, n_to_smallers = create_graph(rules)
print(n_to_greaters)
print(n_to_smallers)

print(total_middle_valid_correcting(updates, n_to_greaters, n_to_smallers))
# Out:
# {11: {16, 17, 24, 25, 26, 28, 29, 31, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 12: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 14: {11, 12, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 16: {14, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 84, 87, 88, 96, 97}, 17: {14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 22: {11, 16, 17, 24, 25, 27, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 24: {14, 16, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 25: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 96, 98}, 26: {12, 14, 22, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 27: {11, 16, 17, 24, 25, 26, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 28: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 29: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 76, 77, 79, 82, 84, 87, 88, 96}, 31: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 32: {12, 14, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 33: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 65, 67, 76, 77, 78, 87, 93, 97}, 34: {12, 14, 26, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 38: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 43, 47, 52, 55, 56, 57, 63, 65, 67, 76, 77, 78, 93, 97}, 43: {14, 17, 25, 26, 32, 34, 44, 45, 47, 51, 58, 64, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96, 98}, 44: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 93, 94, 98}, 45: {11, 12, 22, 27, 31, 33, 38, 44, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 47: {14, 17, 25, 26, 32, 34, 44, 45, 51, 58, 64, 67, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 49: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 47, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 51: {11, 12, 22, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 52: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 55: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 56: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 58, 64, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 57: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 84, 87, 96, 97}, 58: {11, 12, 22, 27, 28, 31, 33, 38, 49, 51, 52, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 63: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 97}, 64: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 65, 76, 77, 78, 81, 93, 97, 98}, 65: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 67: {14, 17, 25, 26, 32, 34, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 72: {11, 12, 16, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 94, 97, 98}, 73: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 76, 78, 81, 93, 97, 98}, 75: {12, 14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 79, 81, 82, 88, 94, 96, 98}, 76: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 77, 79, 82, 84, 87, 88, 94, 96}, 77: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 78: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 75, 76, 77, 84, 87, 93, 97}, 79: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 57, 58, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 81: {11, 12, 16, 22,  ...
# {11: {12, 14, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 12: {14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 14: {16, 17, 24, 25, 26, 28, 29, 31, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 16: {11, 12, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 93, 94, 98}, 17: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 22: {12, 14, 26, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 24: {11, 12, 22, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 25: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 75, 76, 77, 84, 87, 93, 97}, 26: {11, 16, 17, 24, 25, 27, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 27: {12, 14, 22, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 28: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 57, 58, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 29: {11, 12, 16, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 94, 97, 98}, 31: {11, 12, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 32: {11, 16, 17, 24, 25, 26, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 33: {14, 17, 25, 26, 32, 34, 38, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 88, 94, 96, 98}, 34: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 38: {14, 17, 25, 26, 32, 34, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 43: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 56, 57, 63, 65, 76, 77, 78, 81, 93, 97}, 44: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 45, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 96, 97}, 45: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 47: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 49, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 49: {14, 17, 25, 26, 32, 34, 44, 45, 51, 58, 64, 67, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 51: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 52: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 55: {11, 12, 22, 27, 28, 31, 33, 38, 49, 51, 52, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 56: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 65, 76, 77, 78, 81, 93, 97, 98}, 57: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 93, 94, 98}, 58: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 63: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 96, 98}, 64: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 65: {14, 17, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 67: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 47, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 72: {14, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 82, 84, 87, 88, 96}, 73: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 77, 79, 82, 84, 87, 88, 94, 96}, 75: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 76: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 97, 98}, 77: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 76, 78, 81, 93, 97, 98}, 78: {12, 14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 79, 81, 82, 88, 94, 96, 98}, 79: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 84, 87, 96, 97}, 81: {14, 17, 25, 26,  ...
# 4507

# %% [markdown]
# ## Second Form: Using a dictionary (not working)
#
# The binary relations don't allow to build a [Total order](https://en.wikipedia.org/wiki/Total_order) relationship,
# since for the input.txt some terms break the transivity property

# %%
a = 16
b = 14
c = 82


def manual_smaller(a, b, n_to_greaters, n_to_smallers):
    # a < b
    c1 = b in n_to_greaters.get(a, set())
    c2 = a in n_to_smallers.get(b, set())
    if c1 or c2:
        return True
    # b < a
    c3 = a in n_to_greaters.get(b, set())
    c4 = b in n_to_smallers.get(a, set())
    if c3 or c4:
        return False


res1 = manual_smaller(a, b, n_to_greaters, n_to_smallers)
print(f"{a} < {b} = {res1}")
res5 = manual_smaller(b, c, n_to_greaters, n_to_smallers)
print(f"{b} < {c} = {res5}")
res3 = manual_smaller(a, c, n_to_greaters, n_to_smallers)
print(f"{a} < {c} = {res3}")
# 82 < 16
res2 = manual_smaller(c, a, n_to_greaters, n_to_smallers)
print(f"{c} < {a} = {res2}")
# Out:
# 16 < 14 = True
# 14 < 82 = True
# 16 < 82 = False
# 82 < 16 = True

# %%
# find rules that contains at last two out of the three numbers <16> < <14> < <82>
for rule in rules:
    if (a in rule) + (b in rule) + (c in rule) >= 2:
        print(f"rule: {rule[0]} < {rule[1]}")
# Out:
# rule: 14 < 82
# rule: 16 < 14
# rule: 82 < 16

# %%
class CodeFixed(int):
    def __init__(self, value):
        self.value = value

    def __lt__(self, other):
        return not Code(self.value) >= Code(other.value)

    def __gt__(self, other):
        return not Code(self.value) <= Code(other.value)

    def __eq__(self, other):
        return self.value == other.value

    def __le__(self, other):
        return Code(self.value) <= Code(other.value)

    def __ge__(self, other):
        return Code(self.value) >= Code(other.value)

    def __repr__(self) -> str:
        return f"<{self.value}>"

# %%
def sort_basic(update):
    codes = [Code(i) for i in update]
    codes.sort()
    return tuple(code.value for code in codes)


def get_all_numbers_sorted(rules):
    all_numbers = set()
    for n, greaters in n_to_greaters.items():
        all_numbers.add(n)
        all_numbers.update(greaters)
    for n, smallers in n_to_smallers.items():
        all_numbers.add(n)
        all_numbers.update(smallers)
    sorted_numbers = sort_basic(all_numbers)
    return sorted_numbers

# %%
rules, updates = parse_file("input.txt")
n_to_greaters, n_to_smallers = create_graph(rules)
print(n_to_greaters)
print(n_to_smallers)

print(total_middle_valid_correcting(updates, n_to_greaters, n_to_smallers))
# Out:
# {11: {16, 17, 24, 25, 26, 28, 29, 31, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 12: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 14: {11, 12, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 16: {14, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 84, 87, 88, 96, 97}, 17: {14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 22: {11, 16, 17, 24, 25, 27, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 24: {14, 16, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 25: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 96, 98}, 26: {12, 14, 22, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 27: {11, 16, 17, 24, 25, 26, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 28: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 29: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 76, 77, 79, 82, 84, 87, 88, 96}, 31: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 32: {12, 14, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 33: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 65, 67, 76, 77, 78, 87, 93, 97}, 34: {12, 14, 26, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 38: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 43, 47, 52, 55, 56, 57, 63, 65, 67, 76, 77, 78, 93, 97}, 43: {14, 17, 25, 26, 32, 34, 44, 45, 47, 51, 58, 64, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96, 98}, 44: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 93, 94, 98}, 45: {11, 12, 22, 27, 31, 33, 38, 44, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 47: {14, 17, 25, 26, 32, 34, 44, 45, 51, 58, 64, 67, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 49: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 47, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 51: {11, 12, 22, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 52: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 55: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 56: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 58, 64, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 57: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 84, 87, 96, 97}, 58: {11, 12, 22, 27, 28, 31, 33, 38, 49, 51, 52, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 63: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 97}, 64: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 65, 76, 77, 78, 81, 93, 97, 98}, 65: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 67: {14, 17, 25, 26, 32, 34, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 72: {11, 12, 16, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 94, 97, 98}, 73: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 76, 78, 81, 93, 97, 98}, 75: {12, 14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 79, 81, 82, 88, 94, 96, 98}, 76: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 77, 79, 82, 84, 87, 88, 94, 96}, 77: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 78: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 75, 76, 77, 84, 87, 93, 97}, 79: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 57, 58, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 81: {11, 12, 16, 22,  ...
# {11: {12, 14, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 12: {14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 14: {16, 17, 24, 25, 26, 28, 29, 31, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 16: {11, 12, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 93, 94, 98}, 17: {11, 12, 16, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 22: {12, 14, 26, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 24: {11, 12, 22, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 25: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 75, 76, 77, 84, 87, 93, 97}, 26: {11, 16, 17, 24, 25, 27, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 27: {12, 14, 22, 32, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 28: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 57, 58, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 29: {11, 12, 16, 22, 24, 27, 28, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 94, 97, 98}, 31: {11, 12, 22, 27, 33, 38, 44, 45, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 32: {11, 16, 17, 24, 25, 26, 28, 29, 31, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 33: {14, 17, 25, 26, 32, 34, 38, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 88, 94, 96, 98}, 34: {11, 16, 17, 22, 24, 25, 27, 28, 29, 31, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 38: {14, 17, 25, 26, 32, 34, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 43: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 56, 57, 63, 65, 76, 77, 78, 81, 93, 97}, 44: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 45, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 96, 97}, 45: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 47, 55, 56, 57, 67, 75, 76, 77, 84, 87, 93, 96, 97}, 47: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 49, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 49: {14, 17, 25, 26, 32, 34, 44, 45, 51, 58, 64, 67, 72, 73, 75, 79, 81, 82, 84, 87, 88, 94, 96, 98}, 51: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 56, 58, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 52: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 98}, 55: {11, 12, 22, 27, 28, 31, 33, 38, 49, 51, 52, 57, 63, 64, 65, 72, 73, 78, 81, 82, 88, 93, 94, 98}, 56: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 65, 76, 77, 78, 81, 93, 97, 98}, 57: {11, 12, 22, 27, 31, 33, 38, 49, 51, 52, 58, 63, 64, 65, 72, 73, 78, 79, 81, 82, 88, 93, 94, 98}, 58: {14, 16, 17, 24, 25, 26, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 79, 84, 87, 96, 97}, 63: {12, 14, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 78, 79, 81, 82, 88, 94, 96, 98}, 64: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 73, 75, 79, 82, 84, 87, 88, 94, 96}, 65: {14, 17, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 72, 73, 75, 79, 81, 82, 88, 94, 96, 98}, 67: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 43, 47, 52, 55, 56, 57, 63, 65, 76, 77, 78, 93, 97}, 72: {14, 17, 25, 26, 29, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 75, 76, 77, 79, 82, 84, 87, 88, 96}, 73: {14, 17, 25, 26, 32, 34, 43, 44, 45, 47, 51, 56, 58, 67, 72, 75, 77, 79, 82, 84, 87, 88, 94, 96}, 75: {11, 16, 17, 22, 24, 27, 28, 29, 31, 43, 47, 52, 55, 56, 57, 63, 67, 76, 77, 78, 84, 87, 93, 97}, 76: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 73, 78, 81, 93, 97, 98}, 77: {11, 12, 16, 22, 24, 27, 28, 29, 31, 33, 38, 49, 52, 55, 57, 63, 64, 65, 76, 78, 81, 93, 97, 98}, 78: {12, 14, 25, 26, 32, 33, 34, 38, 44, 45, 49, 51, 58, 64, 65, 72, 73, 79, 81, 82, 88, 94, 96, 98}, 79: {14, 16, 17, 24, 25, 26, 28, 29, 32, 34, 43, 44, 45, 47, 55, 56, 67, 75, 76, 77, 84, 87, 96, 97}, 81: {14, 17, 25, 26,  ...
# 4507

# %%
sorted_numbers = get_all_numbers_sorted(rules)

# %%
def is_total_order(cod_objects, order_relation):
    """
    Check if the given objects define a total order under the given order relation.

    Parameters
    ----------
        cod_objects (list)
        A list of Cod objects to check.
        order_relation (function)
        A function taking two Cod objects and returning True if the first is less than the second.

    Returns
    -------
        bool: True if the objects define a total order, False otherwise.


    References
    ----------
    https://en.wikipedia.org/wiki/Total_order
    """
    n = len(cod_objects)

    output = True
    # Check totality and transitivity
    for i in range(n):
        a = cod_objects[i]
        # Reflexivity: a <= a
        if not order_relation(a, a):
            print(f"Failed reflexivity: {a} and {a}")
            output = False

        for j in range(n):
            b = cod_objects[j]

            # Antisymmetry: if a <= b and b <= a, then a == b
            # (a and b -> c) equiv (!a or !b or c) -> (negating) (a and b and !c)
            if order_relation(a, b) and order_relation(b, a) and (not (a == b)):
                print(f"Failed antisymmetry: {a} and {b}")
                output = False

            # Transitivity: if a < b and b < c, then a < c
            for k in range(n):
                c = cod_objects[k]
                if (
                    order_relation(a, b)
                    and order_relation(b, c)
                    and not order_relation(a, c)
                ):
                    print(f"Failed transitivity: {a} < {b} < {c}")
                    output = False

            # Strongly connected: a <= b or b <= a
            if not (order_relation(a, b) or order_relation(b, a)):
                print(f"Failed strongly connected: {a} and {b}")
                output = False

    return output


def is_strict_total_order(strings, strict_order):
    """
    Check if the given strings define a strict total order under the given strict order relation.

    Parameters
    ----------
        strings (list of str): A list of strings to check.
        strict_order (function): A function taking two strings and returning True if the first is strictly less than the second.

    Returns
    -------
        bool: True if the strings define a strict total order, False otherwise.

    References
    ----------
    https://en.wikipedia.org/wiki/Total_order
    """
    n = len(strings)

    output = True
    # Check irreflexivity, asymmetry, transitivity, and connectedness
    for i in range(n):
        a = strings[i]

        # Irreflexivity: Not a < a
        if strict_order(a, a):
            print(f"Failed irreflexivity: {a} < {a}")
            output = False

        for j in range(n):
            b = strings[j]

            # Asymmetry: if a < b, then not b < a
            if strict_order(a, b) and strict_order(b, a):
                print(f"Failed asymmetry: {a} < {b} and {b} < {a}")
                output = False

            # Connectedness: if a != b, then a < b or b < a
            if a != b and not (strict_order(a, b) or strict_order(b, a)):
                print(f"Failed connectedness: {a} and {b} are not comparable")
                output = False

            for k in range(n):
                c = strings[k]

                # Transitivity: if a < b and b < c, then a < c
                if strict_order(a, b) and strict_order(b, c) and not strict_order(a, c):
                    print(f"Failed transitivity: {a} < {b} < {c}")
                    output = False

    return output


order_relation = lambda a, b: a <= b
strict_order_relation = lambda a, b: a < b


is_total_order([Code(i) for i in sorted_numbers], order_relation)
is_strict_total_order([Code(i) for i in sorted_numbers], strict_order_relation)
sorted_codes = [Code(i) for i in sorted_numbers]
sorted_codes.sort()
print(sorted_codes)
# Out:
# Failed transitivity: <16> < <14> < <82>
# Failed transitivity: <16> < <14> < <72>
# Failed transitivity: <16> < <14> < <94>
# Failed transitivity: <16> < <14> < <73>
# Failed transitivity: <16> < <14> < <64>
# Failed transitivity: <16> < <14> < <98>
# Failed transitivity: <16> < <14> < <81>
# Failed transitivity: <16> < <14> < <49>
# Failed transitivity: <16> < <14> < <38>
# Failed transitivity: <16> < <14> < <33>
# Failed transitivity: <16> < <14> < <65>
# Failed transitivity: <16> < <14> < <12>
# Failed transitivity: <16> < <14> < <78>
# Failed transitivity: <16> < <14> < <63>
# Failed transitivity: <16> < <14> < <52>
# Failed transitivity: <16> < <14> < <22>
# Failed transitivity: <16> < <14> < <27>
# Failed transitivity: <16> < <14> < <11>
# Failed transitivity: <16> < <88> < <82>
# Failed transitivity: <16> < <88> < <72>
# Failed transitivity: <16> < <88> < <94>
# Failed transitivity: <16> < <88> < <73>
# Failed transitivity: <16> < <88> < <64>
# Failed transitivity: <16> < <88> < <98>
# Failed transitivity: <16> < <88> < <81>
# Failed transitivity: <16> < <88> < <49>
# Failed transitivity: <16> < <88> < <38>
# Failed transitivity: <16> < <88> < <33>
# Failed transitivity: <16> < <88> < <65>
# Failed transitivity: <16> < <88> < <12>
# Failed transitivity: <16> < <88> < <78>
# Failed transitivity: <16> < <88> < <63>
# Failed transitivity: <16> < <88> < <52>
# Failed transitivity: <16> < <88> < <22>
# Failed transitivity: <16> < <88> < <27>
# Failed transitivity: <16> < <88> < <11>
# Failed transitivity: <16> < <88> < <31>
# Failed transitivity: <16> < <88> < <93>
# Failed transitivity: <16> < <88> < <57>
# Failed transitivity: <16> < <88> < <28>
# Failed transitivity: <16> < <88> < <55>
# Failed transitivity: <16> < <88> < <24>
# Failed transitivity: <16> < <97> < <82>
# Failed transitivity: <16> < <29> < <82>
# Failed transitivity: <16> < <29> < <72>
# Failed transitivity: <16> < <76> < <82>
# Failed transitivity: <16> < <76> < <72>
# Failed transitivity: <16> < <76> < <94>
# Failed transitivity: <16> < <77> < <82>
# Failed transitivity: <16> < <77> < <72>
# Failed transitivity: <16> < <77> < <94>
# Failed transitivity: <16> < <77> < <73>
# Failed transitivity: <16> < <56> < <82>
# Failed transitivity: <16> < <56> < <72>
# Failed transitivity: <16> < <56> < <94>
# Failed transitivity: <16> < <56> < <73>
# Failed transitivity: <16> < <56> < <64>
# Failed transitivity: <16> < <43> < <82>
# Failed transitivity: <16> < <43> < <72>
# Failed transitivity: <16> < <43> < <94>
# Failed transitivity: <16> < <43> < <73>
# Failed transitivity: <16> < <43> < <64>
# Failed transitivity: <16> < <43> < <98>
# Failed transitivity: <16> < <47> < <82>
# Failed transitivity: <16> < <47> < <72>
# Failed transitivity: <16> < <47> < <94>
# Failed transitivity: <16> < <47> < <73>
# Failed transitivity: <16> < <47> < <64>
# Failed transitivity: <16> < <47> < <98>
# Failed transitivity: <16> < <47> < <81>
# Failed transitivity: <16> < <67> < <82>
# Failed transitivity: <16> < <67> < <72>
# Failed transitivity: <16> < <67> < <94>
# Failed transitivity: <16> < <67> < <73>
# Failed transitivity: <16> < <67> < <64>
# Failed transitivity: <16> < <67> < <98>
# Failed transitivity: <16> < <67> < <81>
# Failed transitivity: <16> < <67> < <49>
# Failed transitivity: <16> < <87> < <82>
# Failed transitivity: <16> < <87> < <72>
# Failed transitivity: <16> < <87> < <94>
# Failed transitivity: <16> < <87> < <73>
# Failed transitivity: <16> < <87> < <64>
# Failed transitivity: <16> < <87> < <98>
# Failed transitivity: <16> < <87> < <81>
# Failed transitivity: <16> < <87> < <49>
# Failed transitivity: <16> < <87> < <38>
# Failed transitivity: <16> < <84> < <82>
# Failed transitivity: <16> < <84> < <72>
# Failed transitivity: <16> < <84> < <94>
# Failed transitivity: <16> < <84> < <73>
# Failed transitivity: <16> < <84> < <64>
# Failed transitivity: <16> < <84> < <98>
# Failed transitivity: <16> < <84> < <81>
# Failed transitivity: <16> < <84> < <49>
# Failed transitivity: <16> < <84> < <38>
# Failed transitivity: <16> < <84> < <33>
# Failed transitivity: <16> < <17> < <82>
# Failed transitivity: <16> < <17> < <72>
# Failed transitivity: <16> < <17> < <94>
# Failed transitivity: <16> < <17> < <73>
# Failed transitivity: <16> < <17> < <64>
# Failed transitivity: <16> < <17> < <98>
# Failed transitivity: <16> < <17> < <81>
# Failed transitivity: <16> < <17> < <49>
# Failed transitivity: <16> < <17> < <38>
# Failed transitivity: <16> < <17> < <33>
# Failed transitivity: <16> < <17> < <65>
# Failed transitivity: <16> < <75> < <82>
# Failed transitivity: <16> < <75> < <72>
# Failed transitivity: <16> < <75> < <94>
# Failed transitivity: <16> < <75> < <73>
# Failed transitivity: <16> < <75> < <64>
# Failed transitivity: <16> < <75> < <98>
# Failed transitivity: <16> < <75> < <81>
# Failed transitivity: <16> < <75> < <49>
# Failed transitivity: <16> < <75> < <38>
# Failed transitivity: <16> < <75> < <33>
# Failed transitivity: <16> < <75> < <65>
# Failed transitivity: <16> < <75> < <12>
# Failed transitivity: <16> < <25> < <82>
# Failed transitivity: <16> < <25> < <72>
# Failed transitivity: <16> < <25> < <94>
# Failed transitivity: <16> < <25> < <73>
# Failed transitivity: <16> < <25> < <64>
# Failed transitivity: <16> < <25> < <98>
# Failed transitivity: <16> < <25> < <81>
# Failed transitivity: <16> < <25> < <49>
# Failed transitivity: <16> < <25> < <38>
# Failed transitivity: <16> < <25> < <33>
# Failed transitivity: <16> < <25> < <65>
# Failed transitivity: <16> < <25> < <12>
# Failed transitivity: <16> < <25> < <78>
# Failed transitivity: <16> < <96> < <82>
# Failed transitivity: <16> < <96> < <72>
# Failed transitivity: <16> < <96> < <94>
# Failed transitivity: <16> < <96> < <73>
# Failed transitivity: <16> < <96> < <64>
# Failed transitivity: <16> < <96> < <98>
# Failed transitivity: <16> < <96> < <81>
# Failed transitivity: <16> < <96> < <49>
# Failed transitivity: <16> < <96> < <38>
# Failed transitivity: <16> < <96> < <33>
# Failed transitivity: <16> < <96> < <65>
# Failed transitivity: <16> < <96> < <12>
# Failed transitivity: <16> < <96> < <78>
# Failed transitivity: <16> < <96> < <63>
# Failed transitivity: <16> < <34> < <82>
# Failed transitivity: <16> < <34> < <72>
# Failed transitivity: <16> < <34> < <94>
# Failed transitivity: <16> < <34> < <73>
# Failed transitivity: <16> < <34> < <64>
# Failed transitivity: <16> < <34> < <98>
# Failed transitivity: <16> < <34> < <81>
# Failed transitivity: <16> < <34> < <49>
# Failed transitivity: <16> < <34> < <38>
# Failed transitivity: <16> < <34> < <33>
# Failed transitivity: <16> < <34> < <65>
# Failed transitivity: <16> < <34> < <12>
# Failed transitivity: <16> < <34> < <78>
# Failed transitivity: <16> < <34> < <63>
# Failed transitivity: <16> < <34> < <52>
# Failed transitivity: <16> < <26> < <82>
# Failed transitivity: <16> < <26> < <72>
# Failed transitivity: <16> < <26> < <94>
# Failed transitivity: <16> < <26> < <73>
# Failed transitivity: <16> < <26> < <64>
# Failed transitivity: <16> < <26> < <98>
# Failed transitivity: <16> < <26> < <81>
# Failed transitivity: <16> < <26> < <49>
# Failed transitivity: <16> < <26> < <38>
# Failed transitivity: <16> < <26> < <33>
# Failed transitivity: <16> < <26> < <65>
# Failed transitivity: <16> < <26> < <12>
# Failed transitivity: <16> < <26> < <78>
# Failed transitivity: <16> < <26> < <63>
# Failed transitivity: <16> < <26> < <52>
# Failed transitivity: <16> < <26> < <22>
# Failed transitivity: <16> < <32> < <82>
# Failed transitivity: <16> < <32> < <72>
# Failed transitivity: <16> < <32> < <94>
# Failed transitivity: <16> < <32> < <73>
# Failed transitivity: <16> < <32> < <64>
# Failed transitivity: <16> < <32> < <98>
# Failed transitivity: <16> < <32> < <81>
# Failed transitivity: <16> < <32> < <49>
# Failed transitivity: <16> < <32> < <38>
# Failed transitivity: <16> < <32> < <33>
# Failed transitivity: <16> < <32> < <65>
# Failed transitivity: <16> < <32> < <12>
# Failed transitivity: <16> < <32> < <78>
# Failed transitivity: <16> < <32> < <63>
# Failed transitivity: <16> < <32> < <52>
# Failed transitivity: <16> < <32> < <22>
# Failed transitivity: <16> < <32> < <27>
# Failed transitivity: <16> < <45> < <82>
# Failed transitivity: <16> < <45> < <72>
# Failed transitivity: <16> < <45> < <94>
# Failed transitivity: <16> < <45> < <73>
# Failed transitivity: <16> < <45> < <64>
# Failed transitivity: <16> < <45> < <98>
# Failed transitivity: <16> < <45> < <81>
# Failed transitivity: <16> < <45> < <49>
# Failed transitivity: <16> < <45> < <38>
# Failed transitivity: <16> < <45> < <33>
# Failed transitivity: <16> < <45> < <65>
# Failed transitivity: <16> < <45> < <12>
# Failed transitivity: <16> < <45> < <78>
# Failed transitivity: <16> < <45> < <63>
# Failed transitivity: <16> < <45> < <52>
# Failed transitivity: <16> < <45> < <22>
# Failed transitivity: <16> < <45> < <27>
# Failed transitivity: <16> < <45> < <11>
# Failed transitivity: <16> < <45> < <31>
# Failed transitivity: <16> < <44> < <82>
# Failed transitivity: <16> < <44> < <72>
# Failed transitivity: <16> < <44> < <94>
# Failed transitivity: <16> < <44> < <73>
# Failed transitivity: <16> < <44> < <64>
# Failed transitivity: <16> < <44> < <98>
# Failed transitivity: <16> < <44> < <81>
# Failed transitivity: <16> < <44> < <49>
# Failed transitivity: <16> < <44> < <38>
# Failed transitivity: <16> < <44> < <33>
# Failed transitivity: <16> < <44> < <65>
# Failed transitivity: <16> < <44> < <12>
# Failed transitivity: <16> < <44> < <78>
# Failed transitivity: <16> < <44> < <63>
# Failed transitivity: <16> < <44> < <52>
# Failed transitivity: <16> < <44> < <22>
# Failed transitivity: <16> < <44> < <27>
# Failed transitivity: <16> < <44> < <11>
# Failed transitivity: <16> < <44> < <31>
# Failed transitivity: <16> < <44> < <93>
# Failed transitivity: <16> < <79> < <82>
# Failed transitivity: <16> < <79> < <72>
# Failed transitivity: <16> < <79> < <94>
# Failed transitivity: <16> < <79> < <73>
# Failed transitivity: <16> < <79> < <64>
# Failed transitivity: <16> < <79> < <98>
# Failed transitivity: <16> < <79> < <81>
# Failed transitivity: <16> < <79> < <49>
# Failed transitivity: <16> < <79> < <38>
# Failed transitivity: <16> < <79> < <33>
# Failed transitivity: <16> < <79> < <65>
# Failed transitivity: <16> < <79> < <12>
# Failed transitivity: <16> < <79> < <78>
# Failed transitivity: <16> < <79> < <63>
# Failed transitivity: <16> < <79> < <52>
# Failed transitivity: <16> < <79> < <22>
# Failed transitivity: <16> < <79> < <27>
# Failed transitivity: <16> < <79> < <11>
# Failed transitivity: <16> < <79> < <31>
# Failed transitivity: <16> < <79> < <93>
# Failed transitivity: <16> < <79> < <57>
# Failed transitivity: <16> < <58> < <82>
# Failed transitivity: <16> < <58> < <72>
# Failed transitivity: <16> < <58> < <94>
# Failed transitivity: <16> < <58> < <73>
# Failed transitivity: <16> < <58> < <64>
# Failed transitivity: <16> < <58> < <98>
# Failed transitivity: <16> < <58> < <81>
# Failed transitivity: <16> < <58> < <49>
# Failed transitivity: <16> < <58> < <38>
# Failed transitivity: <16> < <58> < <33>
# Failed transitivity: <16> < <58> < <65>
# Failed transitivity: <16> < <58> < <12>
# Failed transitivity: <16> < <58> < <78>
# Failed transitivity: <16> < <58> < <63>
# Failed transitivity: <16> < <58> < <52>
# Failed transitivity: <16> < <58> < <22>
# Failed transitivity: <16> < <58> < <27>
# Failed transitivity: <16> < <58> < <11>
# Failed transitivity: <16> < <58> < <31>
# Failed transitivity: <16> < <58> < <93>
# Failed transitivity: <16> < <58> < <57>
# Failed transitivity: <16> < <58> < <28>
# Failed transitivity: <16> < <51> < <82>
# Failed transitivity: <16> < <51> < <72>
# Failed transitivity: <16> < <51> < <94>
# Failed transitivity: <16> < <51> < <73>
# Failed transitivity: <16> < <51> < <64>
# Failed transitivity: <16> < <51> < <98>
# Failed transitivity: <16> < <51> < <81>
# Failed transitivity: <16> < <51> < <49>
# Failed transitivity: <16> < <51> < <38>
# Failed transitivity: <16> < <51> < <33>
# Failed transitivity: <16> < <51> < <65>
# Failed transitivity: <16> < <51> < <12>
# Failed transitivity: <16> < <51> < <78>
# Failed transitivity: <16> < <51> < <63>
# Failed transitivity: <16> < <51> < <52>
# Failed transitivity: <16> < <51> < <22>
# Failed transitivity: <16> < <51> < <27>
# Failed transitivity: <16> < <51> < <11>
# Failed transitivity: <16> < <51> < <31>
# Failed transitivity: <16> < <51> < <93>
# Failed transitivity: <16> < <51> < <57>
# Failed transitivity: <16> < <51> < <28>
# Failed transitivity: <16> < <51> < <55>
# Failed transitivity: <14> < <88> < <31>
# Failed transitivity: <14> < <88> < <93>
# Failed transitivity: <14> < <88> < <57>
# Failed transitivity: <14> < <88> < <28>
# Failed transitivity: <14> < <88> < <55>
# Failed transitivity: <14> < <88> < <24>
# Failed transitivity: <14> < <82> < <16>
# Failed transitivity: <14> < <82> < <31>
# Failed transitivity: <14> < <82> < <93>
# Failed transitivity: <14> < <82> < <57>
# Failed transitivity: <14> < <82> < <28>
# Failed transitivity: <14> < <82> < <55>
# Failed transitivity: <14> < <82> < <24>
# Failed transitivity: <14> < <72> < <16>
# Failed transitivity: <14> < <72> < <31>
# Failed transitivity: <14> < <72> < <93>
# Failed transitivity: <14> < <72> < <57>
# Failed transitivity: <14> < <72> < <28>
# Failed transitivity: <14> < <72> < <55>
# Failed transitivity: <14> < <72> < <24>
# Failed transitivity: <14> < <72> < <97>
# Failed transitivity: <14> < <94> < <16>
# Failed transitivity: <14> < <94> < <31>
# Failed transitivity: <14> < <94> < <93>
# Failed transitivity: <14> < <94> < <57>
# Failed transitivity: <14> < <94> < <28>
# Failed transitivity: <14> < <94> < <55>
# Failed transitivity: <14> < <94> < <24>
# Failed transitivity: <14> < <94> < <97>
# Failed transitivity: <14> < <94> < <29>
# Failed transitivity: <14> < <73> < <16>
# Failed transitivity: <14> < <73> < <31>
# Failed transitivity: <14> < <73> < <93>
# Failed transitivity: <14> < <73> < <57>
# Failed transitivity: <14> < <73> < <28>
# Failed transitivity: <14> < <73> < <55>
# Failed transitivity: <14> < <73> < <24>
# Failed transitivity: <14> < <73> < <97>
# Failed transitivity: <14> < <73> < <29>
# Failed transitivity: <14> < <73> < <76>
# Failed transitivity: <14> < <64> < <16>
# Failed transitivity: <14> < <64> < <31>
# Failed transitivity: <14> < <64> < <93>
# Failed transitivity: <14> < <64> < <57>
# Failed transitivity: <14> < <64> < <28>
# Failed transitivity: <14> < <64> < <55>
# Failed transitivity: <14> < <64> < <24>
# Failed transitivity: <14> < <64> < <97>
# Failed transitivity: <14> < <64> < <29>
# Failed transitivity: <14> < <64> < <76>
# Failed transitivity: <14> < <64> < <77>
# Failed transitivity: <14> < <98> < <16>
# Failed transitivity: <14> < <98> < <31>
# Failed transitivity: <14> < <98> < <93>
# Failed transitivity: <14> < <98> < <57>
# Failed transitivity: <14> < <98> < <28>
# Failed transitivity: <14> < <98> < <55>
# Failed transitivity: <14> < <98> < <24>
# Failed transitivity: <14> < <98> < <97>
# Failed transitivity: <14> < <98> < <29>
# Failed transitivity: <14> < <98> < <76>
# Failed transitivity: <14> < <98> < <77>
# Failed transitivity: <14> < <98> < <56>
# Failed transitivity: <14> < <81> < <16>
# Failed transitivity: <14> < <81> < <31>
# Failed transitivity: <14> < <81> < <93>
# Failed transitivity: <14> < <81> < <57>
# Failed transitivity: <14> < <81> < <28>
# Failed transitivity: <14> < <81> < <55>
# Failed transitivity: <14> < <81> < <24>
# Failed transitivity: <14> < <81> < <97>
# Failed transitivity: <14> < <81> < <29>
# Failed transitivity: <14> < <81> < <76>
# Failed transitivity: <14> < <81> < <77>
# Failed transitivity: <14> < <81> < <56>
# Failed transitivity: <14> < <81> < <43>
# Failed transitivity: <14> < <49> < <16>
# Failed transitivity: <14> < <49> < <31>
# Failed transitivity: <14> < <49> < <93>
# Failed transitivity: <14> < <49> < <57>
# Failed transitivity: <14> < <49> < <28>
# Failed transitivity: <14> < <49> < <55>
# Failed transitivity: <14> < <49> < <24>
# Failed transitivity: <14> < <49> < <97>
# Failed transitivity: <14> < <49> < <29>
# Failed transitivity: <14> < <49> < <76>
# Failed transitivity: <14> < <49> < <77>
# Failed transitivity: <14> < <49> < <56>
# Failed transitivity: <14> < <49> < <43>
# Failed transitivity: <14> < <49> < <47>
# Failed transitivity: <14> < <38> < <16>
# Failed transitivity: <14> < <38> < <31>
# Failed transitivity: <14> < <38> < <93>
# Failed transitivity: <14> < <38> < <57>
# Failed transitivity: <14> < <38> < <28>
# Failed transitivity: <14> < <38> < <55>
# Failed transitivity: <14> < <38> < <24>
# Failed transitivity: <14> < <38> < <97>
# Failed transitivity: <14> < <38> < <29>
# Failed transitivity: <14> < <38> < <76>
# Failed transitivity: <14> < <38> < <77>
# Failed transitivity: <14> < <38> < <56>
# Failed transitivity: <14> < <38> < <43>
# Failed transitivity: <14> < <38> < <47>
# Failed transitivity: <14> < <38> < <67>
# Failed transitivity: <14> < <33> < <16>
# Failed transitivity: <14> < <33> < <31>
# Failed transitivity: <14> < <33> < <93>
# Failed transitivity: <14> < <33> < <57>
# Failed transitivity: <14> < <33> < <28>
# Failed transitivity: <14> < <33> < <55>
# Failed transitivity: <14> < <33> < <24>
# Failed transitivity: <14> < <33> < <97>
# Failed transitivity: <14> < <33> < <29>
# Failed transitivity: <14> < <33> < <76>
# Failed transitivity: <14> < <33> < <77>
# Failed transitivity: <14> < <33> < <56>
# Failed transitivity: <14> < <33> < <43>
# Failed transitivity: <14> < <33> < <47>
# Failed transitivity: <14> < <33> < <67>
# Failed transitivity: <14> < <33> < <87>
# Failed transitivity: <14> < <65> < <16>
# Failed transitivity: <14> < <65> < <31>
# Failed transitivity: <14> < <65> < <93>
# Failed transitivity: <14> < <65> < <57>
# Failed transitivity: <14> < <65> < <28>
# Failed transitivity: <14> < <65> < <55>
# Failed transitivity: <14> < <65> < <24>
# Failed transitivity: <14> < <65> < <97>
# Failed transitivity: <14> < <65> < <29>
# Failed transitivity: <14> < <65> < <76>
# Failed transitivity: <14> < <65> < <77>
# Failed transitivity: <14> < <65> < <56>
# Failed transitivity: <14> < <65> < <43>
# Failed transitivity: <14> < <65> < <47>
# Failed transitivity: <14> < <65> < <67>
# Failed transitivity: <14> < <65> < <87>
# Failed transitivity: <14> < <65> < <84>
# Failed transitivity: <14> < <12> < <16>
# Failed transitivity: <14> < <12> < <31>
# Failed transitivity: <14> < <12> < <93>
# Failed transitivity: <14> < <12> < <57>
# Failed transitivity: <14> < <12> < <28>
# Failed transitivity: <14> < <12> < <55>
# Failed transitivity: <14> < <12> < <24>
# Failed transitivity: <14> < <12> < <97>
# Failed transitivity: <14> < <12> < <29>
# Failed transitivity: <14> < <12> < <76>
# Failed transitivity: <14> < <12> < <77>
# Failed transitivity: <14> < <12> < <56>
# Failed transitivity: <14> < <12> < <43>
# Failed transitivity: <14> < <12> < <47>
# Failed transitivity: <14> < <12> < <67>
# Failed transitivity: <14> < <12> < <87>
# Failed transitivity: <14> < <12> < <84>
# Failed transitivity: <14> < <12> < <17>
# Failed transitivity: <14> < <78> < <16>
# Failed transitivity: <14> < <78> < <31>
# Failed transitivity: <14> < <78> < <93>
# Failed transitivity: <14> < <78> < <57>
# Failed transitivity: <14> < <78> < <28>
# Failed transitivity: <14> < <78> < <55>
# Failed transitivity: <14> < <78> < <24>
# Failed transitivity: <14> < <78> < <97>
# Failed transitivity: <14> < <78> < <29>
# Failed transitivity: <14> < <78> < <76>
# Failed transitivity: <14> < <78> < <77>
# Failed transitivity: <14> < <78> < <56>
# Failed transitivity: <14> < <78> < <43>
# Failed transitivity: <14> < <78> < <47>
# Failed transitivity: <14> < <78> < <67>
# Failed transitivity: <14> < <78> < <87>
# Failed transitivity: <14> < <78> < <84>
# Failed transitivity: <14> < <78> < <17>
# Failed transitivity: <14> < <78> < <75>
# Failed transitivity: <14> < <63> < <16>
# Failed transitivity: <14> < <63> < <31>
# Failed transitivity: <14> < <63> < <93>
# Failed transitivity: <14> < <63> < <57>
# Failed transitivity: <14> < <63> < <28>
# Failed transitivity: <14> < <63> < <55>
# Failed transitivity: <14> < <63> < <24>
# Failed transitivity: <14> < <63> < <97>
# Failed transitivity: <14> < <63> < <29>
# Failed transitivity: <14> < <63> < <76>
# Failed transitivity: <14> < <63> < <77>
# Failed transitivity: <14> < <63> < <56>
# Failed transitivity: <14> < <63> < <43>
# Failed transitivity: <14> < <63> < <47>
# Failed transitivity: <14> < <63> < <67>
# Failed transitivity: <14> < <63> < <87>
# Failed transitivity: <14> < <63> < <84>
# Failed transitivity: <14> < <63> < <17>
# Failed transitivity: <14> < <63> < <75>
# Failed transitivity: <14> < <63> < <25>
# Failed transitivity: <14> < <52> < <16>
# Failed transitivity: <14> < <52> < <31>
# Failed transitivity: <14> < <52> < <93>
# Failed transitivity: <14> < <52> < <57>
# Failed transitivity: <14> < <52> < <28>
# Failed transitivity: <14> < <52> < <55>
# Failed transitivity: <14> < <52> < <24>
# Failed transitivity: <14> < <52> < <97>
# Failed transitivity: <14> < <52> < <29>
# Failed transitivity: <14> < <52> < <76>
# Failed transitivity: <14> < <52> < <77>
# Failed transitivity: <14> < <52> < <56>
# Failed transitivity: <14> < <52> < <43>
# Failed transitivity: <14> < <52> < <47>
# Failed transitivity: <14> < <52> < <67>
# Failed transitivity: <14> < <52> < <87>
# Failed transitivity: <14> < <52> < <84>
# Failed transitivity: <14> < <52> < <17>
# Failed transitivity: <14> < <52> < <75>
# Failed transitivity: <14> < <52> < <25>
# Failed transitivity: <14> < <52> < <96>
# Failed transitivity: <14> < <22> < <16>
# Failed transitivity: <14> < <22> < <31>
# Failed transitivity: <14> < <22> < <93>
# Failed transitivity: <14> < <22> < <57>
# Failed transitivity: <14> < <22> < <28>
# Failed transitivity: <14> < <22> < <55>
# Failed transitivity: <14> < <22> < <24>
# Failed transitivity: <14> < <22> < <97>
# Failed transitivity: <14> < <22> < <29>
# Failed transitivity: <14> < <22> < <76>
# Failed transitivity: <14> < <22> < <77>
# Failed transitivity: <14> < <22> < <56>
# Failed transitivity: <14> < <22> < <43>
# Failed transitivity: <14> < <22> < <47>
# Failed transitivity: <14> < <22> < <67>
# Failed transitivity: <14> < <22> < <87>
# Failed transitivity: <14> < <22> < <84>
# Failed transitivity: <14> < <22> < <17>
# Failed transitivity: <14> < <22> < <75>
# Failed transitivity: <14> < <22> < <25>
# Failed transitivity: <14> < <22> < <96>
# Failed transitivity: <14> < <22> < <34>
# Failed transitivity: <14> < <27> < <16>
# Failed transitivity: <14> < <27> < <31>
# Failed transitivity: <14> < <27> < <93>
# Failed transitivity: <14> < <27> < <57>
# Failed transitivity: <14> < <27> < <28>
# Failed transitivity: <14> < <27> < <55>
# Failed transitivity: <14> < <27> < <24>
# Failed transitivity: <14> < <27> < <97>
# Failed transitivity: <14> < <27> < <29>
# Failed transitivity: <14> < <27> < <76>
# Failed transitivity: <14> < <27> < <77>
# Failed transitivity: <14> < <27> < <56>
# Failed transitivity: <14> < <27> < <43>
# Failed transitivity: <14> < <27> < <47>
# Failed transitivity: <14> < <27> < <67>
# Failed transitivity: <14> < <27> < <87>
# Failed transitivity: <14> < <27> < <84>
# Failed transitivity: <14> < <27> < <17>
# Failed transitivity: <14> < <27> < <75>
# Failed transitivity: <14> < <27> < <25>
# Failed transitivity: <14> < <27> < <96>
# Failed transitivity: <14> < <27> < <34>
# Failed transitivity: <14> < <27> < <26>
# Failed transitivity: <14> < <11> < <16>
# Failed transitivity: <14> < <11> < <31>
# Failed transitivity: <14> < <11> < <93>
# Failed transitivity: <14> < <11> < <57>
# Failed transitivity: <14> < <11> < <28>
# Failed transitivity: <14> < <11> < <55>
# Failed transitivity: <14> < <11> < <24>
# Failed transitivity: <14> < <11> < <97>
# Failed transitivity: <14> < <11> < <29>
# Failed transitivity: <14> < <11> < <76>
# Failed transitivity: <14> < <11> < <77>
# Failed transitivity: <14> < <11> < <56>
# Failed transitivity: <14> < <11> < <43>
# Failed transitivity: <14> < <11> < <47>
# Failed transitivity: <14> < <11> < <67>
# Failed transitivity: <14> < <11> < <87>
# Failed transitivity: <14> < <11> < <84>
# Failed transitivity: <14> < <11> < <17>
# Failed transitivity: <14> < <11> < <75>
# Failed transitivity: <14> < <11> < <25>
# Failed transitivity: <14> < <11> < <96>
# Failed transitivity: <14> < <11> < <34>
# Failed transitivity: <14> < <11> < <26>
# Failed transitivity: <14> < <11> < <32>
# Failed transitivity: <14> < <45> < <31>
# Failed transitivity: <14> < <44> < <31>
# Failed transitivity: <14> < <44> < <93>
# Failed transitivity: <14> < <79> < <31>
# Failed transitivity: <14> < <79> < <93>
# Failed transitivity: <14> < <79> < <57>
# Failed transitivity: <14> < <58> < <31>
# Failed transitivity: <14> < <58> < <93>
# Failed transitivity: <14> < <58> < <57>
# Failed transitivity: <14> < <58> < <28>
# Failed transitivity: <14> < <51> < <31>
# Failed transitivity: <14> < <51> < <93>
# Failed transitivity: <14> < <51> < <57>
# Failed transitivity: <14> < <51> < <28>
# Failed transitivity: <14> < <51> < <55>
# Failed transitivity: <88> < <82> < <16>
# Failed transitivity: <88> < <72> < <16>
# Failed transitivity: <88> < <72> < <97>
# Failed transitivity: <88> < <94> < <16>
# Failed transitivity: <88> < <94> < <97>
# Failed transitivity: <88> < <94> < <29>
# Failed transitivity: <88> < <73> < <16>
# Failed transitivity: <88> < <73> < <97>
# Failed transitivity: <88> < <73> < <29>
# Failed transitivity: <88> < <73> < <76>
# Failed transitivity: <88> < <64> < <16>
# Failed transitivity: <88> < <64> < <97>
# Failed transitivity: <88> < <64> < <29>
# Failed transitivity: <88> < <64> < <76>
# Failed transitivity: <88> < <64> < <77>
# Failed transitivity: <88> < <98> < <16>
# Failed transitivity: <88> < <98> < <97>
# Failed transitivity: <88> < <98> < <29>
# Failed transitivity: <88> < <98> < <76>
# Failed transitivity: <88> < <98> < <77>
# Failed transitivity: <88> < <98> < <56>
# Failed transitivity: <88> < <81> < <16>
# Failed transitivity: <88> < <81> < <97>
# Failed transitivity: <88> < <81> < <29>
# Failed transitivity: <88> < <81> < <76>
# Failed transitivity: <88> < <81> < <77>
# Failed transitivity: <88> < <81> < <56>
# Failed transitivity: <88> < <81> < <43>
# Failed transitivity: <88> < <49> < <16>
# Failed transitivity: <88> < <49> < <97>
# Failed transitivity: <88> < <49> < <29>
# Failed transitivity: <88> < <49> < <76>
# Failed transitivity: <88> < <49> < <77>
# Failed transitivity: <88> < <49> < <56>
# Failed transitivity: <88> < <49> < <43>
# Failed transitivity: <88> < <49> < <47>
# Failed transitivity: <88> < <38> < <16>
# Failed transitivity: <88> < <38> < <97>
# Failed transitivity: <88> < <38> < <29>
# Failed transitivity: <88> < <38> < <76>
# Failed transitivity: <88> < <38> < <77>
# Failed transitivity: <88> < <38> < <56>
# Failed transitivity: <88> < <38> < <43>
# Failed transitivity: <88> < <38> < <47>
# Failed transitivity: <88> < <38> < <67>
# Failed transitivity: <88> < <33> < <16>
# Failed transitivity: <88> < <33> < <97>
# Failed transitivity: <88> < <33> < <29>
# Failed transitivity: <88> < <33> < <76>
# Failed transitivity: <88> < <33> < <77>
# Failed transitivity: <88> < <33> < <56>
# Failed transitivity: <88> < <33> < <43>
# Failed transitivity: <88> < <33> < <47>
# Failed transitivity: <88> < <33> < <67>
# Failed transitivity: <88> < <33> < <87>
# Failed transitivity: <88> < <65> < <16>
# Failed transitivity: <88> < <65> < <97>
# Failed transitivity: <88> < <65> < <29>
# Failed transitivity: <88> < <65> < <76>
# Failed transitivity: <88> < <65> < <77>
# Failed transitivity: <88> < <65> < <56>
# Failed transitivity: <88> < <65> < <43>
# Failed transitivity: <88> < <65> < <47>
# Failed transitivity: <88> < <65> < <67>
# Failed transitivity: <88> < <65> < <87>
# Failed transitivity: <88> < <65> < <84>
# Failed transitivity: <88> < <12> < <16>
# Failed transitivity: <88> < <12> < <97>
# Failed transitivity: <88> < <12> < <29>
# Failed transitivity: <88> < <12> < <76>
# Failed transitivity: <88> < <12> < <77>
# Failed transitivity: <88> < <12> < <56>
# Failed transitivity: <88> < <12> < <43>
# Failed transitivity: <88> < <12> < <47>
# Failed transitivity: <88> < <12> < <67>
# Failed transitivity: <88> < <12> < <87>
# Failed transitivity: <88> < <12> < <84>
# Failed transitivity: <88> < <12> < <17>
# Failed transitivity: <88> < <78> < <16>
# Failed transitivity: <88> < <78> < <97>
# Failed transitivity: <88> < <78> < <29>
# Failed transitivity: <88> < <78> < <76>
# Failed transitivity: <88> < <78> < <77>
# Failed transitivity: <88> < <78> < <56>
# Failed transitivity: <88> < <78> < <43>
# Failed transitivity: <88> < <78> < <47>
# Failed transitivity: <88> < <78> < <67>
# Failed transitivity: <88> < <78> < <87>
# Failed transitivity: <88> < <78> < <84>
# Failed transitivity: <88> < <78> < <17>
# Failed transitivity: <88> < <78> < <75>
# Failed transitivity: <88> < <63> < <16>
# Failed transitivity: <88> < <63> < <97>
# Failed transitivity: <88> < <63> < <29>
# Failed transitivity: <88> < <63> < <76>
# Failed transitivity: <88> < <63> < <77>
# Failed transitivity: <88> < <63> < <56>
# Failed transitivity: <88> < <63> < <43>
# Failed transitivity: <88> < <63> < <47>
# Failed transitivity: <88> < <63> < <67>
# Failed transitivity: <88> < <63> < <87>
# Failed transitivity: <88> < <63> < <84>
# Failed transitivity: <88> < <63> < <17>
# Failed transitivity: <88> < <63> < <75>
# Failed transitivity: <88> < <63> < <25>
# Failed transitivity: <88> < <52> < <16>
# Failed transitivity: <88> < <52> < <97>
# Failed transitivity: <88> < <52> < <29>
# Failed transitivity: <88> < <52> < <76>
# Failed transitivity: <88> < <52> < <77>
# Failed transitivity: <88> < <52> < <56>
# Failed transitivity: <88> < <52> < <43>
# Failed transitivity: <88> < <52> < <47>
# Failed transitivity: <88> < <52> < <67>
# Failed transitivity: <88> < <52> < <87>
# Failed transitivity: <88> < <52> < <84>
# Failed transitivity: <88> < <52> < <17>
# Failed transitivity: <88> < <52> < <75>
# Failed transitivity: <88> < <52> < <25>
# Failed transitivity: <88> < <52> < <96>
# Failed transitivity: <88> < <22> < <16>
# Failed transitivity: <88> < <22> < <97>
# Failed transitivity: <88> < <22> < <29>
# Failed transitivity: <88> < <22> < <76>
# Failed transitivity: <88> < <22> < <77>
# Failed transitivity: <88> < <22> < <56>
# Failed transitivity: <88> < <22> < <43>
# Failed transitivity: <88> < <22> < <47>
# Failed transitivity: <88> < <22> < <67>
# Failed transitivity: <88> < <22> < <87>
# Failed transitivity: <88> < <22> < <84>
# Failed transitivity: <88> < <22> < <17>
# Failed transitivity: <88> < <22> < <75>
# Failed transitivity: <88> < <22> < <25>
# Failed transitivity: <88> < <22> < <96>
# Failed transitivity: <88> < <22> < <34>
# Failed transitivity: <88> < <27> < <16>
# Failed transitivity: <88> < <27> < <97>
# Failed transitivity: <88> < <27> < <29>
# Failed transitivity: <88> < <27> < <76>
# Failed transitivity: <88> < <27> < <77>
# Failed transitivity: <88> < <27> < <56>
# Failed transitivity: <88> < <27> < <43>
# Failed transitivity: <88> < <27> < <47>
# Failed transitivity: <88> < <27> < <67>
# Failed transitivity: <88> < <27> < <87>
# Failed transitivity: <88> < <27> < <84>
# Failed transitivity: <88> < <27> < <17>
# Failed transitivity: <88> < <27> < <75>
# Failed transitivity: <88> < <27> < <25>
# Failed transitivity: <88> < <27> < <96>
# Failed transitivity: <88> < <27> < <34>
# Failed transitivity: <88> < <27> < <26>
# Failed transitivity: <88> < <11> < <16>
# Failed transitivity: <88> < <11> < <97>
# Failed transitivity: <88> < <11> < <29>
# Failed transitivity: <88> < <11> < <76>
# Failed transitivity: <88> < <11> < <77>
# Failed transitivity: <88> < <11> < <56>
# Failed transitivity: <88> < <11> < <43>
# Failed transitivity: <88> < <11> < <47>
# Failed transitivity: <88> < <11> < <67>
# Failed transitivity: <88> < <11> < <87>
# Failed transitivity: <88> < <11> < <84>
# Failed transitivity: <88> < <11> < <17>
# Failed transitivity: <88> < <11> < <75>
# Failed transitivity: <88> < <11> < <25>
# Failed transitivity: <88> < <11> < <96>
# Failed transitivity: <88> < <11> < <34>
# Failed transitivity: <88> < <11> < <26>
# Failed transitivity: <88> < <11> < <32>
# Failed transitivity: <88> < <31> < <16>
# Failed transitivity: <88> < <31> < <14>
# Failed transitivity: <88> < <31> < <97>
# Failed transitivity: <88> < <31> < <29>
# Failed transitivity: <88> < <31> < <76>
# Failed transitivity: <88> < <31> < <77>
# Failed transitivity: <88> < <31> < <56>
# Failed transitivity: <88> < <31> < <43>
# Failed transitivity: <88> < <31> < <47>
# Failed transitivity: <88> < <31> < <67>
# Failed transitivity: <88> < <31> < <87>
# Failed transitivity: <88> < <31> < <84>
# Failed transitivity: <88> < <31> < <17>
# Failed transitivity: <88> < <31> < <75>
# Failed transitivity: <88> < <31> < <25>
# Failed transitivity: <88> < <31> < <96>
# Failed transitivity: <88> < <31> < <34>
# Failed transitivity: <88> < <31> < <26>
# Failed transitivity: <88> < <31> < <32>
# Failed transitivity: <88> < <93> < <16>
# Failed transitivity: <88> < <93> < <14>
# Failed transitivity: <88> < <93> < <97>
# Failed transitivity: <88> < <93> < <29>
# Failed transitivity: <88> < <93> < <76>
# Failed transitivity: <88> < <93> < <77>
# Failed transitivity: <88> < <93> < <56>
# Failed transitivity: <88> < <93> < <43>
# Failed transitivity: <88> < <93> < <47>
# Failed transitivity: <88> < <93> < <67>
# Failed transitivity: <88> < <93> < <87>
# Failed transitivity: <88> < <93> < <84>
# Failed transitivity: <88> < <93> < <17>
# Failed transitivity: <88> < <93> < <75>
# Failed transitivity: <88> < <93> < <25>
# Failed transitivity: <88> < <93> < <96>
# Failed transitivity: <88> < <93> < <34>
# Failed transitivity: <88> < <93> < <26>
# Failed transitivity: <88> < <93> < <32>
# Failed transitivity: <88> < <93> < <45>
# Failed transitivity: <88> < <57> < <16>
# Failed transitivity: <88> < <57> < <14>
# Failed transitivity: <88> < <57> < <97>
# Failed transitivity: <88> < <57> < <29>
# Failed transitivity: <88> < <57> < <76>
# Failed transitivity: <88> < <57> < <77>
# Failed transitivity: <88> < <57> < <56>
# Failed transitivity: <88> < <57> < <43>
# Failed transitivity: <88> < <57> < <47>
# Failed transitivity: <88> < <57> < <67>
# Failed transitivity: <88> < <57> < <87>
# Failed transitivity: <88> < <57> < <84>
# Failed transitivity: <88> < <57> < <17>
# Failed transitivity: <88> < <57> < <75>
# Failed transitivity: <88> < <57> < <25>
# Failed transitivity: <88> < <57> < <96>
# Failed transitivity: <88> < <57> < <34>
# Failed transitivity: <88> < <57> < <26>
# Failed transitivity: <88> < <57> < <32>
# Failed transitivity: <88> < <57> < <45>
# Failed transitivity: <88> < <57> < <44>
# Failed transitivity: <88> < <28> < <16>
# Failed transitivity: <88> < <28> < <14>
# Failed transitivity: <88> < <28> < <97>
# Failed transitivity: <88> < <28> < <29>
# Failed transitivity: <88> < <28> < <76>
# Failed transitivity: <88> < <28> < <77>
# Failed transitivity: <88> < <28> < <56>
# Failed transitivity: <88> < <28> < <43>
# Failed transitivity: <88> < <28> < <47>
# Failed transitivity: <88> < <28> < <67>
# Failed transitivity: <88> < <28> < <87>
# Failed transitivity: <88> < <28> < <84>
# Failed transitivity: <88> < <28> < <17>
# Failed transitivity: <88> < <28> < <75>
# Failed transitivity: <88> < <28> < <25>
# Failed transitivity: <88> < <28> < <96>
# Failed transitivity: <88> < <28> < <34>
# Failed transitivity: <88> < <28> < <26>
# Failed transitivity: <88> < <28> < <32>
# Failed transitivity: <88> < <28> < <45>
# Failed transitivity: <88> < <28> < <44>
# Failed transitivity: <88> < <28> < <79>
# Failed transitivity: <88> < <55> < <16>
# Failed transitivity: <88> < <55> < <14>
# Failed transitivity: <88> < <55> < <97>
# Failed transitivity: <88> < <55> < <29>
# Failed transitivity: <88> < <55> < <76>
# Failed transitivity: <88> < <55> < <77>
# Failed transitivity: <88> < <55> < <56>
# Failed transitivity: <88> < <55> < <43>
# Failed transitivity: <88> < <55> < <47>
# Failed transitivity: <88> < <55> < <67>
# Failed transitivity: <88> < <55> < <87>
# Failed transitivity: <88> < <55> < <84>
# Failed transitivity: <88> < <55> < <17>
# Failed transitivity: <88> < <55> < <75>
# Failed transitivity: <88> < <55> < <25>
# Failed transitivity: <88> < <55> < <96>
# Failed transitivity: <88> < <55> < <34>
# Failed transitivity: <88> < <55> < <26>
# Failed transitivity: <88> < <55> < <32>
# Failed transitivity: <88> < <55> < <45>
# Failed transitivity: <88> < <55> < <44>
# Failed transitivity: <88> < <55> < <79>
# Failed transitivity: <88> < <55> < <58>
# Failed transitivity: <88> < <24> < <16>
# Failed transitivity: <88> < <24> < <14>
# Failed transitivity: <88> < <24> < <97>
# Failed transitivity: <88> < <24> < <29>
# Failed transitivity: <88> < <24> < <76>
# Failed transitivity: <88> < <24> < <77>
# Failed transitivity: <88> < <24> < <56>
# Failed transitivity: <88> < <24> < <43>
# Failed transitivity: <88> < <24> < <47>
# Failed transitivity: <88> < <24> < <67>
# Failed transitivity: <88> < <24> < <87>
# Failed transitivity: <88> < <24> < <84>
# Failed transitivity: <88> < <24> < <17>
# Failed transitivity: <88> < <24> < <75>
# Failed transitivity: <88> < <24> < <25>
# Failed transitivity: <88> < <24> < <96>
# Failed transitivity: <88> < <24> < <34>
# Failed transitivity: <88> < <24> < <26>
# Failed transitivity: <88> < <24> < <32>
# Failed transitivity: <88> < <24> < <45>
# Failed transitivity: <88> < <24> < <44>
# Failed transitivity: <88> < <24> < <79>
# Failed transitivity: <88> < <24> < <58>
# Failed transitivity: <88> < <24> < <51>
# Failed transitivity: <82> < <16> < <14>
# Failed transitivity: <82> < <16> < <88>
# Failed transitivity: <82> < <16> < <97>
# Failed transitivity: <82> < <16> < <29>
# Failed transitivity: <82> < <16> < <76>
# Failed transitivity: <82> < <16> < <77>
# Failed transitivity: <82> < <16> < <56>
# Failed transitivity: <82> < <16> < <43>
# Failed transitivity: <82> < <16> < <47>
# Failed transitivity: <82> < <16> < <67>
# Failed transitivity: <82> < <16> < <87>
# Failed transitivity: <82> < <16> < <84>
# Failed transitivity: <82> < <16> < <17>
# Failed transitivity: <82> < <16> < <75>
# Failed transitivity: <82> < <16> < <25>
# Failed transitivity: <82> < <16> < <96>
# Failed transitivity: <82> < <16> < <34>
# Failed transitivity: <82> < <16> < <26>
# Failed transitivity: <82> < <16> < <32>
# Failed transitivity: <82> < <16> < <45>
# Failed transitivity: <82> < <16> < <44>
# Failed transitivity: <82> < <16> < <79>
# Failed transitivity: <82> < <16> < <58>
# Failed transitivity: <82> < <16> < <51>
# Failed transitivity: <82> < <72> < <97>
# Failed transitivity: <82> < <94> < <97>
# Failed transitivity: <82> < <94> < <29>
# Failed transitivity: <82> < <73> < <97>
# Failed transitivity: <82> < <73> < <29>
# Failed transitivity: <82> < <73> < <76>
# Failed transitivity: <82> < <64> < <97>
# Failed transitivity: <82> < <64> < <29>
# Failed transitivity: <82> < <64> < <76>
# Failed transitivity: <82> < <64> < <77>
# Failed transitivity: <82> < <98> < <97>
# Failed transitivity: <82> < <98> < <29>
# Failed transitivity: <82> < <98> < <76>
# Failed transitivity: <82> < <98> < <77>
# Failed transitivity: <82> < <98> < <56>
# Failed transitivity: <82> < <81> < <97>
# Failed transitivity: <82> < <81> < <29>
# Failed transitivity: <82> < <81> < <76>
# Failed transitivity: <82> < <81> < <77>
# Failed transitivity: <82> < <81> < <56>
# Failed transitivity: <82> < <81> < <43>
# Failed transitivity: <82> < <49> < <97>
# Failed transitivity: <82> < <49> < <29>
# Failed transitivity: <82> < <49> < <76>
# Failed transitivity: <82> < <49> < <77>
# Failed transitivity: <82> < <49> < <56>
# Failed transitivity: <82> < <49> < <43>
# Failed transitivity: <82> < <49> < <47>
# Failed transitivity: <82> < <38> < <97>
# Failed transitivity: <82> < <38> < <29>
# Failed transitivity: <82> < <38> < <76>
# Failed transitivity: <82> < <38> < <77>
# Failed transitivity: <82> < <38> < <56>
# Failed transitivity: <82> < <38> < <43>
# Failed transitivity: <82> < <38> < <47>
# Failed transitivity: <82> < <38> < <67>
# Failed transitivity: <82> < <33> < <97>
# Failed transitivity: <82> < <33> < <29>
# Failed transitivity: <82> < <33> < <76>
# Failed transitivity: <82> < <33> < <77>
# Failed transitivity: <82> < <33> < <56>
# Failed transitivity: <82> < <33> < <43>
# Failed transitivity: <82> < <33> < <47>
# Failed transitivity: <82> < <33> < <67>
# Failed transitivity: <82> < <33> < <87>
# Failed transitivity: <82> < <65> < <97>
# Failed transitivity: <82> < <65> < <29>
# Failed transitivity: <82> < <65> < <76>
# Failed transitivity: <82> < <65> < <77>
# Failed transitivity: <82> < <65> < <56>
# Failed transitivity: <82> < <65> < <43>
# Failed transitivity: <82> < <65> < <47>
# Failed transitivity: <82> < <65> < <67>
# Failed transitivity: <82> < <65> < <87>
# Failed transitivity: <82> < <65> < <84>
# Failed transitivity: <82> < <12> < <97>
# Failed transitivity: <82> < <12> < <29>
# Failed transitivity: <82> < <12> < <76>
# Failed transitivity: <82> < <12> < <77>
# Failed transitivity: <82> < <12> < <56>
# Failed transitivity: <82> < <12> < <43>
# Failed transitivity: <82> < <12> < <47>
# Failed transitivity: <82> < <12> < <67>
# Failed transitivity: <82> < <12> < <87>
# Failed transitivity: <82> < <12> < <84>
# Failed transitivity: <82> < <12> < <17>
# Failed transitivity: <82> < <78> < <97>
# Failed transitivity: <82> < <78> < <29>
# Failed transitivity: <82> < <78> < <76>
# Failed transitivity: <82> < <78> < <77>
# Failed transitivity: <82> < <78> < <56>
# Failed transitivity: <82> < <78> < <43>
# Failed transitivity: <82> < <78> < <47>
# Failed transitivity: <82> < <78> < <67>
# Failed transitivity: <82> < <78> < <87>
# Failed transitivity: <82> < <78> < <84>
# Failed transitivity: <82> < <78> < <17>
# Failed transitivity: <82> < <78> < <75>
# Failed transitivity: <82> < <63> < <97>
# Failed transitivity: <82> < <63> < <29>
# Failed transitivity: <82> < <63> < <76>
# Failed transitivity: <82> < <63> < <77>
# Failed transitivity: <82> < <63> < <56>
# Failed transitivity: <82> < <63> < <43>
# Failed transitivity: <82> < <63> < <47>
# Failed transitivity: <82> < <63> < <67>
# Failed transitivity: <82> < <63> < <87>
# Failed transitivity: <82> < <63> < <84>
# Failed transitivity: <82> < <63> < <17>
# Failed transitivity: <82> < <63> < <75>
# Failed transitivity: <82> < <63> < <25>
# Failed transitivity: <82> < <52> < <97>
# Failed transitivity: <82> < <52> < <29>
# Failed transitivity: <82> < <52> < <76>
# Failed transitivity: <82> < <52> < <77>
# Failed transitivity: <82> < <52> < <56>
# Failed transitivity: <82> < <52> < <43>
# Failed transitivity: <82> < <52> < <47>
# Failed transitivity: <82> < <52> < <67>
# Failed transitivity: <82> < <52> < <87>
# Failed transitivity: <82> < <52> < <84>
# Failed transitivity: <82> < <52> < <17>
# Failed transitivity: <82> < <52> < <75>
# Failed transitivity: <82> < <52> < <25>
# Failed transitivity: <82> < <52> < <96>
# Failed transitivity: <82> < <22> < <97>
# Failed transitivity: <82> < <22> < <29>
# Failed transitivity: <82> < <22> < <76>
# Failed transitivity: <82> < <22> < <77>
# Failed transitivity: <82> < <22> < <56>
# Failed transitivity: <82> < <22> < <43>
# Failed transitivity: <82> < <22> < <47>
# Failed transitivity: <82> < <22> < <67>
# Failed transitivity: <82> < <22> < <87>
# Failed transitivity: <82> < <22> < <84>
# Failed transitivity: <82> < <22> < <17>
# Failed transitivity: <82> < <22> < <75>
# Failed transitivity: <82> < <22> < <25>
# Failed transitivity: <82> < <22> < <96>
# Failed transitivity: <82> < <22> < <34>
# Failed transitivity: <82> < <27> < <97>
# Failed transitivity: <82> < <27> < <29>
# Failed transitivity: <82> < <27> < <76>
# Failed transitivity: <82> < <27> < <77>
# Failed transitivity: <82> < <27> < <56>
# Failed transitivity: <82> < <27> < <43>
# Failed transitivity: <82> < <27> < <47>
# Failed transitivity: <82> < <27> < <67>
# Failed transitivity: <82> < <27> < <87>
# Failed transitivity: <82> < <27> < <84>
# Failed transitivity: <82> < <27> < <17>
# Failed transitivity: <82> < <27> < <75>
# Failed transitivity: <82> < <27> < <25>
# Failed transitivity: <82> < <27> < <96>
# Failed transitivity: <82> < <27> < <34>
# Failed transitivity: <82> < <27> < <26>
# Failed transitivity: <82> < <11> < <97>
# Failed transitivity: <82> < <11> < <29>
# Failed transitivity: <82> < <11> < <76>
# Failed transitivity: <82> < <11> < <77>
# Failed transitivity: <82> < <11> < <56>
# Failed transitivity: <82> < <11> < <43>
# Failed transitivity: <82> < <11> < <47>
# Failed transitivity: <82> < <11> < <67>
# Failed transitivity: <82> < <11> < <87>
# Failed transitivity: <82> < <11> < <84>
# Failed transitivity: <82> < <11> < <17>
# Failed transitivity: <82> < <11> < <75>
# Failed transitivity: <82> < <11> < <25>
# Failed transitivity: <82> < <11> < <96>
# Failed transitivity: <82> < <11> < <34>
# Failed transitivity: <82> < <11> < <26>
# Failed transitivity: <82> < <11> < <32>
# Failed transitivity: <82> < <31> < <14>
# Failed transitivity: <82> < <31> < <97>
# Failed transitivity: <82> < <31> < <29>
# Failed transitivity: <82> < <31> < <76>
# Failed transitivity: <82> < <31> < <77>
# Failed transitivity: <82> < <31> < <56>
# Failed transitivity: <82> < <31> < <43>
# Failed transitivity: <82> < <31> < <47>
# Failed transitivity: <82> < <31> < <67>
# Failed transitivity: <82> < <31> < <87>
# Failed transitivity: <82> < <31> < <84>
# Failed transitivity: <82> < <31> < <17>
# Failed transitivity: <82> < <31> < <75>
# Failed transitivity: <82> < <31> < <25>
# Failed transitivity: <82> < <31> < <96>
# Failed transitivity: <82> < <31> < <34>
# Failed transitivity: <82> < <31> < <26>
# Failed transitivity: <82> < <31> < <32>
# Failed transitivity: <82> < <93> < <14>
# Failed transitivity: <82> < <93> < <97>
# Failed transitivity: <82> < <93> < <29>
# Failed transitivity: <82> < <93> < <76>
# Failed transitivity: <82> < <93> < <77>
# Failed transitivity: <82> < <93> < <56>
# Failed transitivity: <82> < <93> < <43>
# Failed transitivity: <82> < <93> < <47>
# Failed transitivity: <82> < <93> < <67>
# Failed transitivity: <82> < <93> < <87>
# Failed transitivity: <82> < <93> < <84>
# Failed transitivity: <82> < <93> < <17>
# Failed transitivity: <82> < <93> < <75>
# Failed transitivity: <82> < <93> < <25>
# Failed transitivity: <82> < <93> < <96>
# Failed transitivity: <82> < <93> < <34>
# Failed transitivity: <82> < <93> < <26>
# Failed transitivity: <82> < <93> < <32>
# Failed transitivity: <82> < <93> < <45>
# Failed transitivity: <82> < <57> < <14>
# Failed transitivity: <82> < <57> < <97>
# Failed transitivity: <82> < <57> < <29>
# Failed transitivity: <82> < <57> < <76>
# Failed transitivity: <82> < <57> < <77>
# Failed transitivity: <82> < <57> < <56>
# Failed transitivity: <82> < <57> < <43>
# Failed transitivity: <82> < <57> < <47>
# Failed transitivity: <82> < <57> < <67>
# Failed transitivity: <82> < <57> < <87>
# Failed transitivity: <82> < <57> < <84>
# Failed transitivity: <82> < <57> < <17>
# Failed transitivity: <82> < <57> < <75>
# Failed transitivity: <82> < <57> < <25>
# Failed transitivity: <82> < <57> < <96>
# Failed transitivity: <82> < <57> < <34>
# Failed transitivity: <82> < <57> < <26>
# Failed transitivity: <82> < <57> < <32>
# Failed transitivity: <82> < <57> < <45>
# Failed transitivity: <82> < <57> < <44>
# Failed transitivity: <82> < <28> < <14>
# Failed transitivity: <82> < <28> < <97>
# Failed transitivity: <82> < <28> < <29>
# Failed transitivity: <82> < <28> < <76>
# Failed transitivity: <82> < <28> < <77>
# Failed transitivity: <82> < <28> < <56>
# Failed transitivity: <82> < <28> < <43>
# Failed transitivity: <82> < <28> < <47>
# Failed transitivity: <82> < <28> < <67>
# Failed transitivity: <82> < <28> < <87>
# Failed transitivity: <82> < <28> < <84>
# Failed transitivity: <82> < <28> < <17>
# Failed transitivity: <82> < <28> < <75>
# Failed transitivity: <82> < <28> < <25>
# Failed transitivity: <82> < <28> < <96>
# Failed transitivity: <82> < <28> < <34>
# Failed transitivity: <82> < <28> < <26>
# Failed transitivity: <82> < <28> < <32>
# Failed transitivity: <82> < <28> < <45>
# Failed transitivity: <82> < <28> < <44>
# Failed transitivity: <82> < <28> < <79>
# Failed transitivity: <82> < <55> < <14>
# Failed transitivity: <82> < <55> < <97>
# Failed transitivity: <82> < <55> < <29>
# Failed transitivity: <82> < <55> < <76>
# Failed transitivity: <82> < <55> < <77>
# Failed transitivity: <82> < <55> < <56>
# Failed transitivity: <82> < <55> < <43>
# Failed transitivity: <82> < <55> < <47>
# Failed transitivity: <82> < <55> < <67>
# Failed transitivity: <82> < <55> < <87>
# Failed transitivity: <82> < <55> < <84>
# Failed transitivity: <82> < <55> < <17>
# Failed transitivity: <82> < <55> < <75>
# Failed transitivity: <82> < <55> < <25>
# Failed transitivity: <82> < <55> < <96>
# Failed transitivity: <82> < <55> < <34>
# Failed transitivity: <82> < <55> < <26>
# Failed transitivity: <82> < <55> < <32>
# Failed transitivity: <82> < <55> < <45>
# Failed transitivity: <82> < <55> < <44>
# Failed transitivity: <82> < <55> < <79>
# Failed transitivity: <82> < <55> < <58>
# Failed transitivity: <82> < <24> < <14>
# Failed transitivity: <82> < <24> < <97>
# Failed transitivity: <82> < <24> < <29>
# Failed transitivity: <82> < <24> < <76>
# Failed transitivity: <82> < <24> < <77>
# Failed transitivity: <82> < <24> < <56>
# Failed transitivity: <82> < <24> < <43>
# Failed transitivity: <82> < <24> < <47>
# Failed transitivity: <82> < <24> < <67>
# Failed transitivity: <82> < <24> < <87>
# Failed transitivity: <82> < <24> < <84>
# Failed transitivity: <82> < <24> < <17>
# Failed transitivity: <82> < <24> < <75>
# Failed transitivity: <82> < <24> < <25>
# Failed transitivity: <82> < <24> < <96>
# Failed transitivity: <82> < <24> < <34>
# Failed transitivity: <82> < <24> < <26>
# Failed transitivity: <82> < <24> < <32>
# Failed transitivity: <82> < <24> < <45>
# Failed transitivity: <82> < <24> < <44>
# Failed transitivity: <82> < <24> < <79>
# Failed transitivity: <82> < <24> < <58>
# Failed transitivity: <82> < <24> < <51>
# ...
# Failed transitivity: <58> < <11> < <32>
# Failed transitivity: <58> < <31> < <16>
# Failed transitivity: <58> < <31> < <14>
# Failed transitivity: <58> < <31> < <55>
# Failed transitivity: <58> < <31> < <24>
# Failed transitivity: <58> < <31> < <97>
# Failed transitivity: <58> < <31> < <29>
# Failed transitivity: <58> < <31> < <76>
# Failed transitivity: <58> < <31> < <77>
# Failed transitivity: <58> < <31> < <56>
# Failed transitivity: <58> < <31> < <43>
# Failed transitivity: <58> < <31> < <47>
# Failed transitivity: <58> < <31> < <67>
# Failed transitivity: <58> < <31> < <87>
# Failed transitivity: <58> < <31> < <84>
# Failed transitivity: <58> < <31> < <17>
# Failed transitivity: <58> < <31> < <75>
# Failed transitivity: <58> < <31> < <25>
# Failed transitivity: <58> < <31> < <96>
# Failed transitivity: <58> < <31> < <34>
# Failed transitivity: <58> < <31> < <26>
# Failed transitivity: <58> < <31> < <32>
# Failed transitivity: <58> < <93> < <16>
# Failed transitivity: <58> < <93> < <14>
# Failed transitivity: <58> < <93> < <55>
# Failed transitivity: <58> < <93> < <24>
# Failed transitivity: <58> < <93> < <97>
# Failed transitivity: <58> < <93> < <29>
# Failed transitivity: <58> < <93> < <76>
# Failed transitivity: <58> < <93> < <77>
# Failed transitivity: <58> < <93> < <56>
# Failed transitivity: <58> < <93> < <43>
# Failed transitivity: <58> < <93> < <47>
# Failed transitivity: <58> < <93> < <67>
# Failed transitivity: <58> < <93> < <87>
# Failed transitivity: <58> < <93> < <84>
# Failed transitivity: <58> < <93> < <17>
# Failed transitivity: <58> < <93> < <75>
# Failed transitivity: <58> < <93> < <25>
# Failed transitivity: <58> < <93> < <96>
# Failed transitivity: <58> < <93> < <34>
# Failed transitivity: <58> < <93> < <26>
# Failed transitivity: <58> < <93> < <32>
# Failed transitivity: <58> < <93> < <45>
# Failed transitivity: <58> < <57> < <16>
# Failed transitivity: <58> < <57> < <14>
# Failed transitivity: <58> < <57> < <55>
# Failed transitivity: <58> < <57> < <24>
# Failed transitivity: <58> < <57> < <97>
# Failed transitivity: <58> < <57> < <29>
# Failed transitivity: <58> < <57> < <76>
# Failed transitivity: <58> < <57> < <77>
# Failed transitivity: <58> < <57> < <56>
# Failed transitivity: <58> < <57> < <43>
# Failed transitivity: <58> < <57> < <47>
# Failed transitivity: <58> < <57> < <67>
# Failed transitivity: <58> < <57> < <87>
# Failed transitivity: <58> < <57> < <84>
# Failed transitivity: <58> < <57> < <17>
# Failed transitivity: <58> < <57> < <75>
# Failed transitivity: <58> < <57> < <25>
# Failed transitivity: <58> < <57> < <96>
# Failed transitivity: <58> < <57> < <34>
# Failed transitivity: <58> < <57> < <26>
# Failed transitivity: <58> < <57> < <32>
# Failed transitivity: <58> < <57> < <45>
# Failed transitivity: <58> < <57> < <44>
# Failed transitivity: <58> < <28> < <16>
# Failed transitivity: <58> < <28> < <14>
# Failed transitivity: <58> < <28> < <55>
# Failed transitivity: <58> < <28> < <24>
# Failed transitivity: <58> < <28> < <97>
# Failed transitivity: <58> < <28> < <29>
# Failed transitivity: <58> < <28> < <76>
# Failed transitivity: <58> < <28> < <77>
# Failed transitivity: <58> < <28> < <56>
# Failed transitivity: <58> < <28> < <43>
# Failed transitivity: <58> < <28> < <47>
# Failed transitivity: <58> < <28> < <67>
# Failed transitivity: <58> < <28> < <87>
# Failed transitivity: <58> < <28> < <84>
# Failed transitivity: <58> < <28> < <17>
# Failed transitivity: <58> < <28> < <75>
# Failed transitivity: <58> < <28> < <25>
# Failed transitivity: <58> < <28> < <96>
# Failed transitivity: <58> < <28> < <34>
# Failed transitivity: <58> < <28> < <26>
# Failed transitivity: <58> < <28> < <32>
# Failed transitivity: <58> < <28> < <45>
# Failed transitivity: <58> < <28> < <44>
# Failed transitivity: <58> < <28> < <79>
# Failed transitivity: <58> < <51> < <55>
# Failed transitivity: <51> < <88> < <24>
# Failed transitivity: <51> < <82> < <16>
# Failed transitivity: <51> < <82> < <24>
# Failed transitivity: <51> < <72> < <16>
# Failed transitivity: <51> < <72> < <24>
# Failed transitivity: <51> < <72> < <97>
# Failed transitivity: <51> < <94> < <16>
# Failed transitivity: <51> < <94> < <24>
# Failed transitivity: <51> < <94> < <97>
# Failed transitivity: <51> < <94> < <29>
# Failed transitivity: <51> < <73> < <16>
# Failed transitivity: <51> < <73> < <24>
# Failed transitivity: <51> < <73> < <97>
# Failed transitivity: <51> < <73> < <29>
# Failed transitivity: <51> < <73> < <76>
# Failed transitivity: <51> < <64> < <16>
# Failed transitivity: <51> < <64> < <24>
# Failed transitivity: <51> < <64> < <97>
# Failed transitivity: <51> < <64> < <29>
# Failed transitivity: <51> < <64> < <76>
# Failed transitivity: <51> < <64> < <77>
# Failed transitivity: <51> < <98> < <16>
# Failed transitivity: <51> < <98> < <24>
# Failed transitivity: <51> < <98> < <97>
# Failed transitivity: <51> < <98> < <29>
# Failed transitivity: <51> < <98> < <76>
# Failed transitivity: <51> < <98> < <77>
# Failed transitivity: <51> < <98> < <56>
# Failed transitivity: <51> < <81> < <16>
# Failed transitivity: <51> < <81> < <24>
# Failed transitivity: <51> < <81> < <97>
# Failed transitivity: <51> < <81> < <29>
# Failed transitivity: <51> < <81> < <76>
# Failed transitivity: <51> < <81> < <77>
# Failed transitivity: <51> < <81> < <56>
# Failed transitivity: <51> < <81> < <43>
# Failed transitivity: <51> < <49> < <16>
# Failed transitivity: <51> < <49> < <24>
# Failed transitivity: <51> < <49> < <97>
# Failed transitivity: <51> < <49> < <29>
# Failed transitivity: <51> < <49> < <76>
# Failed transitivity: <51> < <49> < <77>
# Failed transitivity: <51> < <49> < <56>
# Failed transitivity: <51> < <49> < <43>
# Failed transitivity: <51> < <49> < <47>
# Failed transitivity: <51> < <38> < <16>
# Failed transitivity: <51> < <38> < <24>
# Failed transitivity: <51> < <38> < <97>
# Failed transitivity: <51> < <38> < <29>
# Failed transitivity: <51> < <38> < <76>
# Failed transitivity: <51> < <38> < <77>
# Failed transitivity: <51> < <38> < <56>
# Failed transitivity: <51> < <38> < <43>
# Failed transitivity: <51> < <38> < <47>
# Failed transitivity: <51> < <38> < <67>
# Failed transitivity: <51> < <33> < <16>
# Failed transitivity: <51> < <33> < <24>
# Failed transitivity: <51> < <33> < <97>
# Failed transitivity: <51> < <33> < <29>
# Failed transitivity: <51> < <33> < <76>
# Failed transitivity: <51> < <33> < <77>
# Failed transitivity: <51> < <33> < <56>
# Failed transitivity: <51> < <33> < <43>
# Failed transitivity: <51> < <33> < <47>
# Failed transitivity: <51> < <33> < <67>
# Failed transitivity: <51> < <33> < <87>
# Failed transitivity: <51> < <65> < <16>
# Failed transitivity: <51> < <65> < <24>
# Failed transitivity: <51> < <65> < <97>
# Failed transitivity: <51> < <65> < <29>
# Failed transitivity: <51> < <65> < <76>
# Failed transitivity: <51> < <65> < <77>
# Failed transitivity: <51> < <65> < <56>
# Failed transitivity: <51> < <65> < <43>
# Failed transitivity: <51> < <65> < <47>
# Failed transitivity: <51> < <65> < <67>
# Failed transitivity: <51> < <65> < <87>
# Failed transitivity: <51> < <65> < <84>
# Failed transitivity: <51> < <12> < <16>
# Failed transitivity: <51> < <12> < <24>
# Failed transitivity: <51> < <12> < <97>
# Failed transitivity: <51> < <12> < <29>
# Failed transitivity: <51> < <12> < <76>
# Failed transitivity: <51> < <12> < <77>
# Failed transitivity: <51> < <12> < <56>
# Failed transitivity: <51> < <12> < <43>
# Failed transitivity: <51> < <12> < <47>
# Failed transitivity: <51> < <12> < <67>
# Failed transitivity: <51> < <12> < <87>
# Failed transitivity: <51> < <12> < <84>
# Failed transitivity: <51> < <12> < <17>
# Failed transitivity: <51> < <78> < <16>
# Failed transitivity: <51> < <78> < <24>
# Failed transitivity: <51> < <78> < <97>
# Failed transitivity: <51> < <78> < <29>
# Failed transitivity: <51> < <78> < <76>
# Failed transitivity: <51> < <78> < <77>
# Failed transitivity: <51> < <78> < <56>
# Failed transitivity: <51> < <78> < <43>
# Failed transitivity: <51> < <78> < <47>
# Failed transitivity: <51> < <78> < <67>
# Failed transitivity: <51> < <78> < <87>
# Failed transitivity: <51> < <78> < <84>
# Failed transitivity: <51> < <78> < <17>
# Failed transitivity: <51> < <78> < <75>
# Failed transitivity: <51> < <63> < <16>
# Failed transitivity: <51> < <63> < <24>
# Failed transitivity: <51> < <63> < <97>
# Failed transitivity: <51> < <63> < <29>
# Failed transitivity: <51> < <63> < <76>
# Failed transitivity: <51> < <63> < <77>
# Failed transitivity: <51> < <63> < <56>
# Failed transitivity: <51> < <63> < <43>
# Failed transitivity: <51> < <63> < <47>
# Failed transitivity: <51> < <63> < <67>
# Failed transitivity: <51> < <63> < <87>
# Failed transitivity: <51> < <63> < <84>
# Failed transitivity: <51> < <63> < <17>
# Failed transitivity: <51> < <63> < <75>
# Failed transitivity: <51> < <63> < <25>
# Failed transitivity: <51> < <52> < <16>
# Failed transitivity: <51> < <52> < <24>
# Failed transitivity: <51> < <52> < <97>
# Failed transitivity: <51> < <52> < <29>
# Failed transitivity: <51> < <52> < <76>
# Failed transitivity: <51> < <52> < <77>
# Failed transitivity: <51> < <52> < <56>
# Failed transitivity: <51> < <52> < <43>
# Failed transitivity: <51> < <52> < <47>
# Failed transitivity: <51> < <52> < <67>
# Failed transitivity: <51> < <52> < <87>
# Failed transitivity: <51> < <52> < <84>
# Failed transitivity: <51> < <52> < <17>
# Failed transitivity: <51> < <52> < <75>
# Failed transitivity: <51> < <52> < <25>
# Failed transitivity: <51> < <52> < <96>
# Failed transitivity: <51> < <22> < <16>
# Failed transitivity: <51> < <22> < <24>
# Failed transitivity: <51> < <22> < <97>
# Failed transitivity: <51> < <22> < <29>
# Failed transitivity: <51> < <22> < <76>
# Failed transitivity: <51> < <22> < <77>
# Failed transitivity: <51> < <22> < <56>
# Failed transitivity: <51> < <22> < <43>
# Failed transitivity: <51> < <22> < <47>
# Failed transitivity: <51> < <22> < <67>
# Failed transitivity: <51> < <22> < <87>
# Failed transitivity: <51> < <22> < <84>
# Failed transitivity: <51> < <22> < <17>
# Failed transitivity: <51> < <22> < <75>
# Failed transitivity: <51> < <22> < <25>
# Failed transitivity: <51> < <22> < <96>
# Failed transitivity: <51> < <22> < <34>
# Failed transitivity: <51> < <27> < <16>
# Failed transitivity: <51> < <27> < <24>
# Failed transitivity: <51> < <27> < <97>
# Failed transitivity: <51> < <27> < <29>
# Failed transitivity: <51> < <27> < <76>
# Failed transitivity: <51> < <27> < <77>
# Failed transitivity: <51> < <27> < <56>
# Failed transitivity: <51> < <27> < <43>
# Failed transitivity: <51> < <27> < <47>
# Failed transitivity: <51> < <27> < <67>
# Failed transitivity: <51> < <27> < <87>
# Failed transitivity: <51> < <27> < <84>
# Failed transitivity: <51> < <27> < <17>
# Failed transitivity: <51> < <27> < <75>
# Failed transitivity: <51> < <27> < <25>
# Failed transitivity: <51> < <27> < <96>
# Failed transitivity: <51> < <27> < <34>
# Failed transitivity: <51> < <27> < <26>
# Failed transitivity: <51> < <11> < <16>
# Failed transitivity: <51> < <11> < <24>
# Failed transitivity: <51> < <11> < <97>
# Failed transitivity: <51> < <11> < <29>
# Failed transitivity: <51> < <11> < <76>
# Failed transitivity: <51> < <11> < <77>
# Failed transitivity: <51> < <11> < <56>
# Failed transitivity: <51> < <11> < <43>
# Failed transitivity: <51> < <11> < <47>
# Failed transitivity: <51> < <11> < <67>
# Failed transitivity: <51> < <11> < <87>
# Failed transitivity: <51> < <11> < <84>
# Failed transitivity: <51> < <11> < <17>
# Failed transitivity: <51> < <11> < <75>
# Failed transitivity: <51> < <11> < <25>
# Failed transitivity: <51> < <11> < <96>
# Failed transitivity: <51> < <11> < <34>
# Failed transitivity: <51> < <11> < <26>
# Failed transitivity: <51> < <11> < <32>
# Failed transitivity: <51> < <31> < <16>
# Failed transitivity: <51> < <31> < <14>
# Failed transitivity: <51> < <31> < <24>
# Failed transitivity: <51> < <31> < <97>
# Failed transitivity: <51> < <31> < <29>
# Failed transitivity: <51> < <31> < <76>
# Failed transitivity: <51> < <31> < <77>
# Failed transitivity: <51> < <31> < <56>
# Failed transitivity: <51> < <31> < <43>
# Failed transitivity: <51> < <31> < <47>
# Failed transitivity: <51> < <31> < <67>
# Failed transitivity: <51> < <31> < <87>
# Failed transitivity: <51> < <31> < <84>
# Failed transitivity: <51> < <31> < <17>
# Failed transitivity: <51> < <31> < <75>
# Failed transitivity: <51> < <31> < <25>
# Failed transitivity: <51> < <31> < <96>
# Failed transitivity: <51> < <31> < <34>
# Failed transitivity: <51> < <31> < <26>
# Failed transitivity: <51> < <31> < <32>
# Failed transitivity: <51> < <93> < <16>
# Failed transitivity: <51> < <93> < <14>
# Failed transitivity: <51> < <93> < <24>
# Failed transitivity: <51> < <93> < <97>
# Failed transitivity: <51> < <93> < <29>
# Failed transitivity: <51> < <93> < <76>
# Failed transitivity: <51> < <93> < <77>
# Failed transitivity: <51> < <93> < <56>
# Failed transitivity: <51> < <93> < <43>
# Failed transitivity: <51> < <93> < <47>
# Failed transitivity: <51> < <93> < <67>
# Failed transitivity: <51> < <93> < <87>
# Failed transitivity: <51> < <93> < <84>
# Failed transitivity: <51> < <93> < <17>
# Failed transitivity: <51> < <93> < <75>
# Failed transitivity: <51> < <93> < <25>
# Failed transitivity: <51> < <93> < <96>
# Failed transitivity: <51> < <93> < <34>
# Failed transitivity: <51> < <93> < <26>
# Failed transitivity: <51> < <93> < <32>
# Failed transitivity: <51> < <93> < <45>
# Failed transitivity: <51> < <57> < <16>
# Failed transitivity: <51> < <57> < <14>
# Failed transitivity: <51> < <57> < <24>
# Failed transitivity: <51> < <57> < <97>
# Failed transitivity: <51> < <57> < <29>
# Failed transitivity: <51> < <57> < <76>
# Failed transitivity: <51> < <57> < <77>
# Failed transitivity: <51> < <57> < <56>
# Failed transitivity: <51> < <57> < <43>
# Failed transitivity: <51> < <57> < <47>
# Failed transitivity: <51> < <57> < <67>
# Failed transitivity: <51> < <57> < <87>
# Failed transitivity: <51> < <57> < <84>
# Failed transitivity: <51> < <57> < <17>
# Failed transitivity: <51> < <57> < <75>
# Failed transitivity: <51> < <57> < <25>
# Failed transitivity: <51> < <57> < <96>
# Failed transitivity: <51> < <57> < <34>
# Failed transitivity: <51> < <57> < <26>
# Failed transitivity: <51> < <57> < <32>
# Failed transitivity: <51> < <57> < <45>
# Failed transitivity: <51> < <57> < <44>
# Failed transitivity: <51> < <28> < <16>
# Failed transitivity: <51> < <28> < <14>
# Failed transitivity: <51> < <28> < <24>
# Failed transitivity: <51> < <28> < <97>
# Failed transitivity: <51> < <28> < <29>
# Failed transitivity: <51> < <28> < <76>
# Failed transitivity: <51> < <28> < <77>
# Failed transitivity: <51> < <28> < <56>
# Failed transitivity: <51> < <28> < <43>
# Failed transitivity: <51> < <28> < <47>
# Failed transitivity: <51> < <28> < <67>
# Failed transitivity: <51> < <28> < <87>
# Failed transitivity: <51> < <28> < <84>
# Failed transitivity: <51> < <28> < <17>
# Failed transitivity: <51> < <28> < <75>
# Failed transitivity: <51> < <28> < <25>
# Failed transitivity: <51> < <28> < <96>
# Failed transitivity: <51> < <28> < <34>
# Failed transitivity: <51> < <28> < <26>
# Failed transitivity: <51> < <28> < <32>
# Failed transitivity: <51> < <28> < <45>
# Failed transitivity: <51> < <28> < <44>
# Failed transitivity: <51> < <28> < <79>
# Failed transitivity: <51> < <55> < <16>
# Failed transitivity: <51> < <55> < <14>
# Failed transitivity: <51> < <55> < <24>
# Failed transitivity: <51> < <55> < <97>
# Failed transitivity: <51> < <55> < <29>
# Failed transitivity: <51> < <55> < <76>
# Failed transitivity: <51> < <55> < <77>
# Failed transitivity: <51> < <55> < <56>
# Failed transitivity: <51> < <55> < <43>
# Failed transitivity: <51> < <55> < <47>
# Failed transitivity: <51> < <55> < <67>
# Failed transitivity: <51> < <55> < <87>
# Failed transitivity: <51> < <55> < <84>
# Failed transitivity: <51> < <55> < <17>
# Failed transitivity: <51> < <55> < <75>
# Failed transitivity: <51> < <55> < <25>
# Failed transitivity: <51> < <55> < <96>
# Failed transitivity: <51> < <55> < <34>
# Failed transitivity: <51> < <55> < <26>
# Failed transitivity: <51> < <55> < <32>
# Failed transitivity: <51> < <55> < <45>
# Failed transitivity: <51> < <55> < <44>
# Failed transitivity: <51> < <55> < <79>
# Failed transitivity: <51> < <55> < <58>
# [<16>, <14>, <88>, <82>, <72>, <94>, <73>, <64>, <98>, <81>, <49>, <38>, <33>, <65>, <12>, <78>, <63>, <52>, <22>, <27>, <11>, <31>, <93>, <57>, <28>, <55>, <24>, <97>, <29>, <76>, <77>, <56>, <43>, <47>, <67>, <87>, <84>, <17>, <75>, <25>, <96>, <34>, <26>, <32>, <45>, <44>, <79>, <58>, <51>]

# %%
order_relation = lambda a, b: a <= b
strict_order_relation = lambda a, b: a < b


test1 = is_total_order([CodeFixed(i) for i in sorted_numbers], order_relation)
print(test1)
test2 = is_strict_total_order(
    [CodeFixed(i) for i in sorted_numbers], strict_order_relation
)
print(test2)

fixed_codes = [CodeFixed(i) for i in sorted_numbers]
fixed_codes.sort()
print(fixed_codes)
# Out:
# True
# True
# [<11>, <12>, <14>, <16>, <17>, <22>, <24>, <25>, <26>, <27>, <28>, <29>, <31>, <32>, <33>, <34>, <38>, <43>, <44>, <45>, <47>, <49>, <51>, <52>, <55>, <56>, <57>, <58>, <63>, <64>, <65>, <67>, <72>, <73>, <75>, <76>, <77>, <78>, <79>, <81>, <82>, <84>, <87>, <88>, <93>, <94>, <96>, <97>, <98>]

# %%
a = 16
b = 14
c = 82
print(Code(a) > Code(b))
print(Code(b) > Code(c))
print(Code(a) > Code(c))
# Out:
# False
# False
# True

# %%
sorted_numbers = get_all_numbers_sorted(rules)
print(sorted_numbers)
print(check_update_valid(sorted_numbers, n_to_greaters, n_to_smallers))
number_to_order = {code: i for i, code in enumerate(sorted_numbers)}
print(number_to_order)
# Out:
# (16, 14, 88, 82, 72, 94, 73, 64, 98, 81, 49, 38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 97, 29, 76, 77, 56, 43, 47, 67, 87, 84, 17, 75, 25, 96, 34, 26, 32, 45, 44, 79, 58, 51)
# False
# {16: 0, 14: 1, 88: 2, 82: 3, 72: 4, 94: 5, 73: 6, 64: 7, 98: 8, 81: 9, 49: 10, 38: 11, 33: 12, 65: 13, 12: 14, 78: 15, 63: 16, 52: 17, 22: 18, 27: 19, 11: 20, 31: 21, 93: 22, 57: 23, 28: 24, 55: 25, 24: 26, 97: 27, 29: 28, 76: 29, 77: 30, 56: 31, 43: 32, 47: 33, 67: 34, 87: 35, 84: 36, 17: 37, 75: 38, 25: 39, 96: 40, 34: 41, 26: 42, 32: 43, 45: 44, 44: 45, 79: 46, 58: 47, 51: 48}

# %%
def insertion_sort(numbers):
    numbers = [Code(n) for n in numbers]
    for i in range(1, len(numbers)):
        j = i
        while j > 0 and numbers[j] < numbers[j - 1]:
            numbers[j], numbers[j - 1] = numbers[j - 1], numbers[j]
            j -= 1

    output = tuple(code.value for code in numbers)
    assert check_update_valid(output, n_to_greaters, n_to_smallers)
    return output


print(sort_basic((16, 82, 14)))
print(sort_basic((82, 14, 16)))

print(insertion_sort((82, 14, 16)))
print(insertion_sort((16, 82, 14)))
# Out:
# (14, 82, 16)
# (16, 14, 82)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 17
#      14 print(sort_basic((16, 82, 14)))
#      15 print(sort_basic((82, 14, 16)))
# ---> 17 print(insertion_sort((82, 14, 16)))
#      18 print(insertion_sort((16, 82, 14)))
#
# Cell In[16], line 10, in insertion_sort(numbers)
#       7         j -= 1
#       9 output = tuple(code.value for code in numbers)
# ---> 10 assert check_update_valid(output, n_to_greaters, n_to_smallers)
#      11 return output
#
# AssertionError:

# %%
for i in range(len(sorted_numbers)):
    for j in range(i + 1, len(sorted_numbers)):
        if not (Code(sorted_numbers[i]) < Code(sorted_numbers[j])):
            print(sorted_numbers[i], sorted_numbers[j])
# Out:
# 16 82
# 16 72
# 16 94
# 16 73
# 16 64
# 16 98
# 16 81
# 16 49
# 16 38
# 16 33
# 16 65
# 16 12
# 16 78
# 16 63
# 16 52
# 16 22
# 16 27
# 16 11
# 16 31
# 16 93
# 16 57
# 16 28
# 16 55
# 16 24
# 14 31
# 14 93
# 14 57
# 14 28
# 14 55
# 14 24
# 14 97
# 14 29
# 14 76
# 14 77
# 14 56
# 14 43
# 14 47
# 14 67
# 14 87
# 14 84
# 14 17
# 14 75
# 14 25
# 14 96
# 14 34
# 14 26
# 14 32
# 88 97
# 88 29
# 88 76
# 88 77
# 88 56
# 88 43
# 88 47
# 88 67
# 88 87
# 88 84
# 88 17
# 88 75
# 88 25
# 88 96
# 88 34
# 88 26
# 88 32
# 88 45
# 88 44
# 88 79
# 88 58
# 88 51
# 82 97
# 82 29
# 82 76
# 82 77
# 82 56
# 82 43
# 82 47
# 82 67
# 82 87
# 82 84
# 82 17
# 82 75
# 82 25
# 82 96
# 82 34
# 82 26
# 82 32
# 82 45
# 82 44
# 82 79
# 82 58
# 82 51
# 72 29
# 72 76
# 72 77
# 72 56
# 72 43
# 72 47
# 72 67
# 72 87
# 72 84
# 72 17
# 72 75
# 72 25
# 72 96
# 72 34
# 72 26
# 72 32
# 72 45
# 72 44
# 72 79
# 72 58
# 72 51
# 94 76
# 94 77
# 94 56
# 94 43
# 94 47
# 94 67
# 94 87
# 94 84
# 94 17
# 94 75
# 94 25
# 94 96
# 94 34
# 94 26
# 94 32
# 94 45
# 94 44
# 94 79
# 94 58
# 94 51
# 73 77
# 73 56
# 73 43
# 73 47
# 73 67
# 73 87
# 73 84
# 73 17
# 73 75
# 73 25
# 73 96
# 73 34
# 73 26
# 73 32
# 73 45
# 73 44
# 73 79
# 73 58
# 73 51
# 64 56
# 64 43
# 64 47
# 64 67
# 64 87
# 64 84
# 64 17
# 64 75
# 64 25
# 64 96
# 64 34
# 64 26
# 64 32
# 64 45
# 64 44
# 64 79
# 64 58
# 64 51
# 98 43
# 98 47
# 98 67
# 98 87
# 98 84
# 98 17
# 98 75
# 98 25
# 98 96
# 98 34
# 98 26
# 98 32
# 98 45
# 98 44
# 98 79
# 98 58
# 98 51
# 81 47
# 81 67
# 81 87
# 81 84
# 81 17
# 81 75
# 81 25
# 81 96
# 81 34
# 81 26
# 81 32
# 81 45
# 81 44
# 81 79
# 81 58
# 81 51
# 49 67
# 49 87
# 49 84
# 49 17
# 49 75
# 49 25
# 49 96
# 49 34
# 49 26
# 49 32
# 49 45
# 49 44
# 49 79
# 49 58
# 49 51
# 38 87
# 38 84
# 38 17
# 38 75
# 38 25
# 38 96
# 38 34
# 38 26
# 38 32
# 38 45
# 38 44
# 38 79
# 38 58
# 38 51
# 33 84
# 33 17
# 33 75
# 33 25
# 33 96
# 33 34
# 33 26
# 33 32
# 33 45
# 33 44
# 33 79
# 33 58
# 33 51
# 65 17
# 65 75
# 65 25
# 65 96
# 65 34
# 65 26
# 65 32
# 65 45
# 65 44
# 65 79
# 65 58
# 65 51
# 12 75
# 12 25
# 12 96
# 12 34
# 12 26
# 12 32
# 12 45
# 12 44
# 12 79
# 12 58
# 12 51
# 78 25
# 78 96
# 78 34
# 78 26
# 78 32
# 78 45
# 78 44
# 78 79
# 78 58
# 78 51
# 63 96
# 63 34
# 63 26
# 63 32
# 63 45
# 63 44
# 63 79
# 63 58
# 63 51
# 52 34
# 52 26
# 52 32
# 52 45
# 52 44
# 52 79
# 52 58
# 52 51
# 22 26
# 22 32
# 22 45
# 22 44
# 22 79
# 22 58
# 22 51
# 27 32
# 27 45
# 27 44
# 27 79
# 27 58
# 27 51
# 11 45
# 11 44
# 11 79
# 11 58
# 11 51
# 31 45
# 31 44
# 31 79
# 31 58
# 31 51
# 93 44
# 93 79
# 93 58
# 93 51
# 57 79
# 57 58
# 57 51
# 28 58
# 28 51
# 55 51

# %%
def sort_dict(update, number_to_order):
    return tuple(sorted(update, key=lambda x: number_to_order[x]))


test = (28, 55, 24, 77, 17, 14, 44)
print(sort_basic(test))
print(sort_dict(test, number_to_order))
# Out:
# (28, 55, 24, 77, 17, 14, 44)
# (14, 28, 55, 24, 77, 17, 44)

# %%
test = (28, 55, 24, 77, 17, 14, 44)
codes = [Code(i) for i in test]
codes.sort()
print(codes)
test_sorted = tuple(sorted(test, key=lambda x: number_to_order[x]))
print(test_sorted)
# Out:
# [<28>, <55>, <24>, <77>, <17>, <14>, <44>]
# (14, 28, 55, 24, 77, 17, 44)

# %%
def total_middle_number(updates, number_to_order, n_to_greaters, n_to_smallers):
    total = 0
    for update in updates:
        sorted_update = tuple(sorted(update, key=lambda x: number_to_order[x]))
        is_equal = sorted_update == update
        is_valid = check_update_valid(update, n_to_greaters, n_to_smallers)
        if not is_equal and is_valid:
            print(update, sorted_update)
        if sorted_update != update:
            central_number = sorted_update[len(sorted_update) // 2]
            total += central_number

    return total


print(total_middle_number(updates, number_to_order, n_to_greaters, n_to_smallers))
# Out:
# (28, 55, 24, 77, 17, 14, 44) (14, 28, 55, 24, 77, 17, 44)
# (87, 84, 17, 25, 45, 44, 88) (88, 87, 84, 17, 25, 45, 44)
# (29, 43, 47, 87, 75, 25, 34, 26, 32, 79, 82) (82, 29, 43, 47, 87, 75, 25, 34, 26, 32, 79)
# (47, 67, 84, 75, 25, 34, 26, 32, 14, 44, 79, 58, 82, 72, 94, 64, 98) (14, 82, 72, 94, 64, 98, 47, 67, 84, 75, 25, 34, 26, 32, 44, 79, 58)
# (72, 73, 98, 81, 78, 22, 27, 11, 57, 28, 55, 24, 16) (16, 72, 73, 98, 81, 78, 22, 27, 11, 57, 28, 55, 24)
# (52, 22, 57, 55, 24, 16, 76, 77, 43, 47, 67, 87, 25) (16, 52, 22, 57, 55, 24, 76, 77, 43, 47, 67, 87, 25)
# (77, 56, 47, 87, 84, 17, 25, 34, 32, 14, 45, 44, 58, 88, 82, 72, 94) (14, 88, 82, 72, 94, 77, 56, 47, 87, 84, 17, 25, 34, 32, 45, 44, 58)
# (38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 16, 97, 76, 77, 56, 43, 47) (16, 38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 97, 76, 77, 56, 43, 47)
# (43, 47, 67, 87, 75, 96, 14, 45, 79, 58, 51, 72, 94, 73, 64) (14, 72, 94, 73, 64, 43, 47, 67, 87, 75, 96, 45, 79, 58, 51)
# (63, 22, 11, 31, 93, 57, 24, 16, 97, 76, 77, 56, 47, 67, 87, 17, 75) (16, 63, 22, 11, 31, 93, 57, 24, 97, 76, 77, 56, 47, 67, 87, 17, 75)
# (32, 14, 45, 44, 58, 51, 88, 72, 73, 98, 81, 49, 38, 65, 12, 78, 63, 52, 22) (14, 88, 72, 73, 98, 81, 49, 38, 65, 12, 78, 63, 52, 22, 32, 45, 44, 58, 51)
# (64, 49, 38, 52, 27, 31, 16, 97, 76) (16, 64, 49, 38, 52, 27, 31, 97, 76)
# (44, 79, 58, 88, 82, 72, 94, 73, 81, 49, 33, 65, 12, 63, 22, 11, 31) (88, 82, 72, 94, 73, 81, 49, 33, 65, 12, 63, 22, 11, 31, 44, 79, 58)
# (93, 57, 28, 16, 97, 76, 43, 47, 67, 87, 75, 25, 96, 34, 26) (16, 93, 57, 28, 97, 76, 43, 47, 67, 87, 75, 25, 96, 34, 26)
# (52, 22, 11, 28, 55, 24, 16, 97, 29, 76, 47, 17, 25) (16, 52, 22, 11, 28, 55, 24, 97, 29, 76, 47, 17, 25)
# (24, 16, 97, 29, 77, 56, 47, 75, 25, 96, 34, 45, 44, 79, 58) (16, 24, 97, 29, 77, 56, 47, 75, 25, 96, 34, 45, 44, 79, 58)
# (87, 84, 17, 25, 96, 34, 32, 14, 45, 79, 58, 51, 88, 82, 72, 94, 73, 64, 98, 81, 49) (14, 88, 82, 72, 94, 73, 64, 98, 81, 49, 87, 84, 17, 25, 96, 34, 32, 45, 79, 58, 51)
# (65, 12, 78, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 16, 97, 29, 76, 77, 56, 43, 47, 67, 87) (16, 65, 12, 78, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 97, 29, 76, 77, 56, 43, 47, 67, 87)
# (43, 67, 84, 96, 34, 32, 58, 88, 72, 73, 64) (88, 72, 73, 64, 43, 67, 84, 96, 34, 32, 58)
# (67, 84, 75, 25, 96, 34, 26, 14, 45, 44, 79, 58, 51, 88, 82, 72, 94, 73, 64) (14, 88, 82, 72, 94, 73, 64, 67, 84, 75, 25, 96, 34, 26, 45, 44, 79, 58, 51)
# (29, 76, 77, 56, 43, 47, 67, 87, 84, 17, 75, 25, 96, 34, 26, 32, 45, 44, 79, 58, 51, 88, 82) (88, 82, 29, 76, 77, 56, 43, 47, 67, 87, 84, 17, 75, 25, 96, 34, 26, 32, 45, 44, 79, 58, 51)
# (81, 49, 38, 33, 65, 78, 22, 27, 11, 31, 93, 57, 16, 97, 76, 77, 56) (16, 81, 49, 38, 33, 65, 78, 22, 27, 11, 31, 93, 57, 97, 76, 77, 56)
# (16, 97, 29, 76, 77, 56, 43, 47, 67, 87, 84, 17, 75, 25, 96, 34, 26, 14, 45, 44, 79, 58, 51) (16, 14, 97, 29, 76, 77, 56, 43, 47, 67, 87, 84, 17, 75, 25, 96, 34, 26, 45, 44, 79, 58, 51)
# (67, 87, 84, 17, 75, 25, 96, 34, 32, 14, 45, 44, 79, 58, 51, 88, 82, 72, 94, 73, 64, 98, 81) (14, 88, 82, 72, 94, 73, 64, 98, 81, 67, 87, 84, 17, 75, 25, 96, 34, 32, 45, 44, 79, 58, 51)
# (31, 93, 28, 16, 97, 76, 77, 56, 47, 87, 84, 17, 25, 96, 34, 26, 32) (16, 31, 93, 28, 97, 76, 77, 56, 47, 87, 84, 17, 25, 96, 34, 26, 32)
# (51, 49, 12, 22, 27) (49, 12, 22, 27, 51)
# (73, 64, 98, 81, 49, 38, 33, 78, 63, 52, 11, 31, 93, 57, 55, 24, 16, 97, 29) (16, 73, 64, 98, 81, 49, 38, 33, 78, 63, 52, 11, 31, 93, 57, 55, 24, 97, 29)
# (98, 81, 38, 65, 52, 31, 57, 28, 16, 29, 77) (16, 98, 81, 38, 65, 52, 31, 57, 28, 29, 77)
# (75, 25, 26, 79, 58, 51, 82, 64, 98, 33, 65) (82, 64, 98, 33, 65, 75, 25, 26, 79, 58, 51)
# (76, 77, 67, 87, 84, 75, 25, 96, 34, 26, 45, 44, 79, 58, 51, 88, 72) (88, 72, 76, 77, 67, 87, 84, 75, 25, 96, 34, 26, 45, 44, 79, 58, 51)
# (26, 45, 79, 88, 82, 72, 94, 98, 81, 49, 38, 63, 52) (88, 82, 72, 94, 98, 81, 49, 38, 63, 52, 26, 45, 79)
# (14, 45, 44, 51, 88, 64, 98, 38, 65, 12, 78, 63, 27) (14, 88, 64, 98, 38, 65, 12, 78, 63, 27, 45, 44, 51)
# (87, 75, 26, 32, 14, 44, 72) (14, 72, 87, 75, 26, 32, 44)
# (94, 73, 64, 98, 49, 38, 65, 78, 52, 11, 93, 57, 16) (16, 94, 73, 64, 98, 49, 38, 65, 78, 52, 11, 93, 57)
# (77, 67, 84, 17, 75, 34, 32, 44, 79, 58, 51, 72, 94) (72, 94, 77, 67, 84, 17, 75, 34, 32, 44, 79, 58, 51)
# (38, 33, 65, 12, 63, 52, 27, 31, 93, 57, 16, 97, 76) (16, 38, 33, 65, 12, 63, 52, 27, 31, 93, 57, 97, 76)
# (34, 26, 32, 14, 45, 44, 79, 58, 51, 88, 82, 72, 94, 73, 64, 98, 81, 49, 38, 65, 12, 78, 63) (14, 88, 82, 72, 94, 73, 64, 98, 81, 49, 38, 65, 12, 78, 63, 34, 26, 32, 45, 44, 79, 58, 51)
# (31, 93, 57, 55, 16, 97, 29, 76, 43, 87, 84, 17, 25, 96, 34, 26, 32) (16, 31, 93, 57, 55, 97, 29, 76, 43, 87, 84, 17, 25, 96, 34, 26, 32)
# (96, 34, 26, 32, 14, 44, 79, 58, 51, 88, 82, 72, 94, 73, 64, 98, 81, 49, 38, 33, 65, 12, 78) (14, 88, 82, 72, 94, 73, 64, 98, 81, 49, 38, 33, 65, 12, 78, 96, 34, 26, 32, 44, 79, 58, 51)
# (56, 43, 47, 87, 84, 17, 25, 96, 26, 14, 45, 44, 79, 58, 88, 82, 72, 94, 73) (14, 88, 82, 72, 94, 73, 56, 43, 47, 87, 84, 17, 25, 96, 26, 45, 44, 79, 58)
# (56, 47, 87, 84, 25, 96, 34, 45, 79, 58, 51, 88, 72) (88, 72, 56, 47, 87, 84, 25, 96, 34, 45, 79, 58, 51)
# (45, 44, 58, 94, 12, 78, 11) (94, 12, 78, 11, 45, 44, 58)
# (38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 93, 28, 55, 24, 16, 97, 29, 76, 77, 43, 47) (16, 38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 93, 28, 55, 24, 97, 29, 76, 77, 43, 47)
# (55, 16, 76, 77, 96, 26, 79) (16, 55, 76, 77, 96, 26, 79)
# (87, 84, 75, 25, 96, 34, 26, 32, 14, 44, 79, 58, 51, 88, 82, 72, 94, 73, 64, 98, 81) (14, 88, 82, 72, 94, 73, 64, 98, 81, 87, 84, 75, 25, 96, 34, 26, 32, 44, 79, 58, 51)
# (63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 16, 97, 29, 76, 77, 56, 43, 47, 67, 84, 17, 75) (16, 63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 97, 29, 76, 77, 56, 43, 47, 67, 84, 17, 75)
# (73, 98, 81, 49, 38, 33, 65, 12, 63, 52, 22, 27, 11, 93, 57, 28, 55, 16, 29) (16, 73, 98, 81, 49, 38, 33, 65, 12, 63, 52, 22, 27, 11, 93, 57, 28, 55, 29)
# (44, 79, 58, 51, 88, 82, 72, 94, 73, 98, 81, 49, 38, 33, 65, 78, 63, 52, 22, 11, 31) (88, 82, 72, 94, 73, 98, 81, 49, 38, 33, 65, 78, 63, 52, 22, 11, 31, 44, 79, 58, 51)
# (25, 96, 26, 45, 58, 51, 72, 94, 64, 98, 81, 65, 12) (72, 94, 64, 98, 81, 65, 12, 25, 96, 26, 45, 58, 51)
# (52, 22, 27, 31, 28, 55, 24, 16, 97, 77, 56, 43, 47, 67, 87, 17, 25) (16, 52, 22, 27, 31, 28, 55, 24, 97, 77, 56, 43, 47, 67, 87, 17, 25)
# (49, 38, 33, 12, 63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 16, 97, 29, 76, 77, 56) (16, 49, 38, 33, 12, 63, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 97, 29, 76, 77, 56)
# (47, 87, 84, 75, 25, 96, 34, 26, 45, 44, 58, 51, 88, 72, 94, 73, 98) (88, 72, 94, 73, 98, 47, 87, 84, 75, 25, 96, 34, 26, 45, 44, 58, 51)
# (28, 16, 29, 67, 87, 14, 44) (16, 14, 28, 29, 67, 87, 44)
# (44, 79, 51, 88, 82, 72, 94, 98, 49, 38, 33, 12, 78, 63, 52, 22, 31) (88, 82, 72, 94, 98, 49, 38, 33, 12, 78, 63, 52, 22, 31, 44, 79, 51)
# (76, 77, 56, 43, 67, 87, 84, 17, 75, 25, 96, 34, 26, 32, 14, 45, 44, 79, 58, 51, 88, 82, 72) (14, 88, 82, 72, 76, 77, 56, 43, 67, 87, 84, 17, 75, 25, 96, 34, 26, 32, 45, 44, 79, 58, 51)
# (65, 12, 78, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 16, 97, 29, 76, 77, 56, 43, 47, 67, 87) (16, 65, 12, 78, 52, 22, 27, 11, 31, 93, 57, 28, 55, 24, 97, 29, 76, 77, 56, 43, 47, 67, 87)
# (45, 94, 64, 33, 52) (94, 64, 33, 52, 45)
# (79, 58, 72, 94, 73, 64, 81, 38, 33, 65, 12, 52, 22, 27, 11, 31, 93) (72, 94, 73, 64, 81, 38, 33, 65, 12, 52, 22, 27, 11, 31, 93, 79, 58)
# (26, 32, 45, 44, 58, 51, 82, 72, 94, 73, 64, 81, 49, 33, 78, 63, 52) (82, 72, 94, 73, 64, 81, 49, 33, 78, 63, 52, 26, 32, 45, 44, 58, 51)
# (79, 58, 51, 88, 94, 64, 98, 49, 38, 33, 65, 12, 78, 63, 11, 31, 93) (88, 94, 64, 98, 49, 38, 33, 65, 12, 78, 63, 11, 31, 93, 79, 58, 51)
# (25, 34, 26, 32, 44, 58, 94, 64, 98, 81, 38, 65, 12) (94, 64, 98, 81, 38, 65, 12, 25, 34, 26, 32, 44, 58)
# (75, 79, 51, 88, 82, 64, 38, 33, 65) (88, 82, 64, 38, 33, 65, 75, 79, 51)
# (55, 24, 97, 29, 76, 77, 56, 43, 67, 87, 84, 17, 75, 25, 96, 26, 14, 45, 79) (14, 55, 24, 97, 29, 76, 77, 56, 43, 67, 87, 84, 17, 75, 25, 96, 26, 45, 79)
# (27, 11, 31, 93, 28, 55, 24, 16, 97, 29, 76, 77, 47, 67, 87, 84, 96) (16, 27, 11, 31, 93, 28, 55, 24, 97, 29, 76, 77, 47, 67, 87, 84, 96)
# (29, 76, 77, 56, 43, 47, 87, 84, 75, 25, 96, 34, 26, 32, 14, 44, 79, 88, 82) (14, 88, 82, 29, 76, 77, 56, 43, 47, 87, 84, 75, 25, 96, 34, 26, 32, 44, 79)
# (51, 82, 72, 94, 64, 98, 49, 38, 12, 78, 63, 52, 22, 27, 31) (82, 72, 94, 64, 98, 49, 38, 12, 78, 63, 52, 22, 27, 31, 51)
# (34, 26, 82, 73, 64, 33, 65, 12, 63) (82, 73, 64, 33, 65, 12, 63, 34, 26)
# (38, 33, 65, 12, 78, 63, 52, 22, 11, 31, 57, 28, 55, 16, 97, 29, 76, 77, 56, 43, 47) (16, 38, 33, 65, 12, 78, 63, 52, 22, 11, 31, 57, 28, 55, 97, 29, 76, 77, 56, 43, 47)
# (51, 94, 73, 64, 98, 81, 33, 12, 78, 22, 27, 11, 31, 93, 28) (94, 73, 64, 98, 81, 33, 12, 78, 22, 27, 11, 31, 93, 28, 51)
# (63, 52, 22, 11, 57, 28, 16, 29, 43, 47, 87, 84, 75) (16, 63, 52, 22, 11, 57, 28, 29, 43, 47, 87, 84, 75)
# (98, 81, 33, 65, 12, 78, 52, 22, 11, 31, 93, 57, 55, 24, 16, 97, 29, 76, 77) (16, 98, 81, 33, 65, 12, 78, 52, 22, 11, 31, 93, 57, 55, 24, 97, 29, 76, 77)
# (47, 67, 87, 84, 75, 34, 26, 14, 58, 82, 98) (14, 82, 98, 47, 67, 87, 84, 75, 34, 26, 58)
# (93, 56, 67, 25, 96, 32, 14) (14, 93, 56, 67, 25, 96, 32)
# (45, 79, 82, 72, 94, 73, 64, 98, 81, 65, 12, 27, 11) (82, 72, 94, 73, 64, 98, 81, 65, 12, 27, 11, 45, 79)
# (87, 17, 25, 34, 26, 45, 44, 79, 88, 82, 73, 64, 98, 81, 49) (88, 82, 73, 64, 98, 81, 49, 87, 17, 25, 34, 26, 45, 44, 79)
# (28, 55, 24, 16, 97, 29, 76, 56, 43, 47, 67, 87, 84, 17, 75, 96, 34, 26, 32, 45, 44) (16, 28, 55, 24, 97, 29, 76, 56, 43, 47, 67, 87, 84, 17, 75, 96, 34, 26, 32, 45, 44)
# (38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 31, 93, 28, 55, 24, 16, 97, 29, 76, 77, 56, 43, 47) (16, 38, 33, 65, 12, 78, 63, 52, 22, 27, 11, 31, 93, 28, 55, 24, 97, 29, 76, 77, 56, 43, 47)
# 8343
